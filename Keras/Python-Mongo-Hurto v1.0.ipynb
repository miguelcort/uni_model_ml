# %% [markdown]
# # Universidad Jorge Tadeo Lozano
#
# ### Taller de Keras
#
# - Extraccion de Datos desde MongoDB
# - Limpieza de Datos con Python
# - Analisis de Sentimiento con Python

# %% [markdown]
# ### Carga de Datos

# %%
import pymongo
from pymongo import MongoClient

# %%
#conexión al servidor local
client = MongoClient('localhost', 27017)

#conexión a la base de datos
db = client.twitterdb

#conexion a la colección hurto para extraer los tweets
collection = db.twitter_hurto

# %%
collection.create_index([('text', 'text')])
# Out:
# 'text_text'

# %%
datos = collection.find({"lang": "es",  "$text": {"$search": "robo"}})

# %%
datos_extraccion = []

# %%
try:
    for dato in datos:
        for key in dato:
            if(key == "text"):
                datos_extraccion.append(dato[key])
            if (key == "extended_tweet"):
                for d in key:
                    if (d == "full_text"):
                        printdatos_extraccion(d)
                        datos_extraccion[len(datos_extraccion):] = [datos_extraccion[key]]
except Exception as err:
    print("Error al imprimir: " + str(err))

# %% [markdown]
# ### Transformación de Datos

# %%
import nltk
from nltk.corpus import stopwords
import string
import unicodedata
import re
import string

# %%
nltk.download('stopwords')
stops = stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosostros',
#  'vosostras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
def remove_accent(text):
    result = [''.join((c for c in unicodedata.normalize('NFD', text) if unicodedata.category(c) != 'Mn'))]
    return result

# %%
#stop words sin acentos
stop_limp = [''.join(remove_accent(x)) for x in stops]

# %%
#tamaño original de la extracción en mongodb
len(datos_extraccion)
# Out:
# 28449

# %%
#Eliminamos los retweets
datos_limp = [x.lower() for x in datos_extraccion if x[:2].lower() != "rt"]

# %%
#Array con usuarios
usuarios = [c.lower() for x in datos_extraccion for c in x.split() if c[:1] == "@"]

# %%
#Array con hashtag
hashtag = [c.lower() for x in datos_extraccion for c in x.split() if c[:1] == "#"]

# %%
#tamaño sin retweets
len(datos_limp)
# Out:
# 10770

# %%
delete_words = [word for x in datos_limp for word in x.split() if len(word) < 3 and word not in ['no','si','da','el','lo','me','es','rt','fe','te','se','ir','ay','va']]

# %%
datos_limp = [x.lower() for x in datos_limp] #tweets en minuscula
datos_limp = [' '.join(word for word in x.split() if word not in (stops) and (stop_limp)) for x in datos_limp] #quitamos las stop words
datos_limp = [' '.join(word for word in x.split() if word not in (usuarios)) for x in datos_limp] #quitamos usuarios
datos_limp = [' '.join(word for word in x.split() if word not in (delete_words)) for x in datos_limp] #quitamos palabras sin sentido do as yu
datos_limp = [' '.join(word for word in x.split() if word not in (hashtag)) for x in datos_limp] #quitamos hashtags

# %%
datos_limp
# Out:
# ['robo, robo gran robo',
#  'robo robo...',
#  'robo robo robo asco da real madrid',
#  'robo plantel educativo, robo transeúnte, robo cuentahabiente, robo repartidor 19… https://t.co/kjgozcstsq',
#  'robo robo robo familia ladrones',
#  'robo robo!!! ratero!!!!!!',
#  'robo robo',
#  'robo robo',
#  'si robo racing comio robo mas grande bernabeu, mas robo baile',
#  'no, excepto opciones, robo energía eléctrica robo robo si codeca ladrones,… https://t.co/uqddgwnijw',
#  'menos foros seguridad, robos trabajo,robo casas hijas, robo teléfono cel… https://t.co/lhq1osrj2q',
#  'robe rena, robo forest, robo haru vez robo ranito. https://t.co/yi7ov9doyd',
#  'robe rena, robo forest, robo haru vez robo ranito. https://t.co/sxq15xaoxr',
#  'robo descarado visca robo farca',
#  'saqueo robo robo delito.',
#  'así sol, robo robo.',
#  'así sol!!robo robo.',
#  'robo robos https://t.co/0rngvhftef',
#  'robo "pena robo" jijiji',
#  'robó jajajajajajaja poesía robo amiga',
#  'saqueo robo, justifica robo.',
#  'así sol, robo robo',
#  'basta robos, llama robo.',
#  'robo mas robo !!! https://t.co/rlrtlf8c1a',
#  'miren robo robo',
#  'temporadas? robo robo amiga',
#  'chavismo rt saqueo robo robo delito.',
#  'veo venir hoy va ser robo tras robo',
#  'día mano mano, hombro hombro, robo robo.',
#  'robo bien uso robó madre',
#  'soles 10,000 soles..robo robo',
#  'robo aquí, robo allá, pinto colores',
#  'usted funes hizo solo robo robo mundo sabe',
#  'desgraciados entienden robo robo aunque sol?',
#  'serio? robo nada. fijate robo gobierno corrupto.',
#  'peor robo puede ser objeto robo tiempo.',
#  'alguien robo (feat. wisin &amp; nacho) sebastian yatra alguien robó (feat. wisin &amp; nacho) single',
#  "¡'robo'... jajaja... frase 'robo españa'.... canalla puede esperar cosa!!!",
#  'protege robos menos robo jajaja https://t.co/ueyf2tkote',
#  'mismas fidel robo, “nacionalización” robo',
#  'totalmente acuerdo contigo arquera, robos, robos buenas acciones, ellos.',
#  'lasallista significa robo cosas... bueno si robo cosas, lasallista',
#  'gran robo público comenzó sept 1973, parado. (robo plus "transición")',
#  'intensidad manejamos familia robo ameo... mentira, robo mil vidas mas',
#  'crees ganó? escuchas fútbol radio? robo friend. puro robo',
#  'robo cuenta lú... pueblo, menos politicos, robo mal',
#  'robo hables difundas estupideces robo empate castaño ganó dos puntos',
#  '.@policiaecuador detiene organización delictiva dedicada robo accesorios vehículos, robo personas… https://t.co/he5rgblijl',
#  'hno cualquiera cristina, cualquiera. nadie puede decir robo, abismal robo.',
#  'robo no. 98092345 miren ete degracimao robó carro. https://t.co/ht3ejreqww https://t.co/arraajjaxd',
#  'seria robo robos, digo... colmo colmos! https://t.co/u4fb7frlkv',
#  'atención! continuan robos ciudadelas. nueva modalidad robo, alquilan departamentos dentro urbanizaciones… https://t.co/vvr62msh9f',
#  'robo tras robo cada eliminatorias, zidane madrid',
#  'robo quedará impune!. viene referendo revocatorio hacer trizas robo colombianos!',
#  'sinónimo narcochavismo-castrista: destrucción, robo muerte, destrucción, robo muerte, destru… https://t.co/7rtlkfbsci',
#  'detienen hombre robo violencia cuentahabiente https://t.co/zvfdpgvmme',
#  'claro, claro no, violacion violacion, robo tampoco robo...',
#  'pronuncia frase: robo hizo: desea practicar robo hábito criminal.',
#  'arcos vallarta constante robo mano armada, robo casa habitación negoci… https://t.co/b8iyksskne',
#  'descaro robo institucionalizado izquierda estado. robo… https://t.co/8zvql3folp',
#  'mojonnn.cero inversion robo total, quitale malpica flores maria gabriela chavez. robo mas descarado nacion',
#  'tipo robo helicóptero, robo armamento militar amenazo muerte presidente https://t.co/y4tm0znuzg',
#  'patrullero evitó robo casino luego robó plata salvó delincuentes https://t.co/jjvhkn2rrb',
#  'vuelve monumental después robo libertadores, gallardo quiere hablar árbitro..volverá robo?',
#  'patrullero evitó robo casino luego robó plata salvó delincuentes https://t.co/gsbvyrmle9',
#  'cuanto robo megacorrupto narcoindultador, robo ams presidentes solo superado po… https://t.co/o5nk9y6uqq',
#  'robo robo usted voto salaverry presidente, ahora dice la… https://t.co/rzbfl11oro',
#  'ascenso llegará robo tras robo cada semana, callarse https://t.co/2ujvrfmenr',
#  'hoy escuela compré café mediano salia $35 nana robo robo, encima horrible',
#  'minuto partido llego 16. internet robo. robo luego yoigo',
#  'hagas parecer supuesto, si robo, robo harto diré,… https://t.co/k6mczax0qd',
#  'públicas robo si tal cerrada porter ganaba empate titularlo"robo año"',
#  'mismo robó rafael ramírez, tuerto andrade panas suyos????? tipo robo',
#  'joda!! vice riber manejando siga robo siga robo!!!!! atraco fantasmas..',
#  'triste ver robo hambre va preso robo fugarla impune',
#  'robo hoy detiene robo vehículos celaya… https://t.co/cmetiwkp4t',
#  'dictador robo plebiscito. error historico robo https://t.co/3u4phqsmdq',
#  'vos das mas robos= coparticipación;;fondo sojero;; aportes truchos(lavado dinero,robo identidad),… https://t.co/d1lt858gjc',
#  'viejo huevon robo robo así robes sol 500000 soles idea viejo cabro',
#  'robo grado tentativa periodista procesaron autores robo periodista romina mariel za… https://t.co/u2xsx1btuh',
#  'podemos decir robo robo menos ... final dos robaron ... caigamos… https://t.co/gews79wcgq',
#  'anunciando intento robo robo, mira mientras herido crescenti,… https://t.co/5vmpdkj3ug',
#  'esque cd9 censura robo cámara ahora robo celular',
#  'robo invernadero asociación conrazones guarda https://t.co/5gcvkhfpct https://t.co/oia8ckpvbr',
#  'mal reparto.. robo robo.. cada día salen casos pasa avisan escapan..',
#  'robo hicieron lyon, robo tercer gol del… https://t.co/ulj6bet69b',
#  'nesecidad igual paro miedo robo siempre uso cicloruta miedo robos carros… https://t.co/hwnxmp7ubb',
#  'cansados robos asaltos, vecinos barrio cuarto detuvieron amarraron sujeto robo una… https://t.co/f972t1tbba',
#  'robo auto robos transeúntes reportan, vigilancia héro… https://t.co/kx15s23yth',
#  'argumenta gobierno peña robo robo ... dudas cambio forma gobernar 🔉🔉🔉🔊 digo... par… https://t.co/woaypyoncm',
#  'saqueo, robo agravantes posible robo (violencia) hurto (sin violencia) acción apod… https://t.co/wxd1oc6tmv',
#  'robo personas robo bancos muestran tendencia creciente, acuerdo comportamiento deli… https://t.co/dy97lw39n0',
#  'presunto robo transeúnte arrestado sujeto apodado “el malilla” presunto robo teléfono celu… https://t.co/qu0ltgr4lw',
#  'robo? si robo ilusión derecho generación intentando ser, desgracia persona',
#  'detienen sujeto tentativa robo domicilio tentativa robo domicilio detenido sujet… https://t.co/85pbmshwll',
#  'disculpas si sono lecciones, llamaste robo, robo, https://t.co/6x4i7sewso',
#  'razón quitaron robo hidrocarburos, cerrando llaves, quitaran robo https://t.co/wds7qyzuep',
#  'robos parte funcionarios confianza gobernador, robo leche desnutridos toneladas cr… https://t.co/zsvzz12qus',
#  '😂😂😂😂se redujo robo hidrocarburos. pues iba bajar robo, si hay, gracias estup… https://t.co/bkvlywojmu',
#  'verdad? flipo, robo tras robo. inviten programa encima… https://t.co/w2mwwrxurn',
#  'presidente iviss carlos rotondaro, robo millones $$$, robo vidas, actuó solo, mu… https://t.co/r6vjcyokbj',
#  'principio, avisar misma comisaría denunció robo. si robo denunció (fail)… https://t.co/oqdgejfmn0',
#  'alto robo vehículos...prevenir puede frustrar robo, invitamos hacer conciencia tomar medidas pu… https://t.co/edlytg49jc',
#  'botar cualquir peronista kirchnerista seguir robo tonses solución fasil pagar impuestos acaba robó',
#  'cambio, idea disimular todas luces solo robo, robo.',
#  'delito comete robo casa habitación, seguido robo vehículos autopartes. https://t.co/mj99eofjiv',
#  'delincuentes sólo hicieron robo violencia sino dicho robo motivado odio hacia perso… https://t.co/veirgdkyxi',
#  'saquear tiendas comida justifica. robo robo. ahora tener hambre derecho ir robar propied… https://t.co/tkxqcbmtc0',
#  'nahh, llegaron final robo, ganaron robo. aplicó reglamento manera injusta… https://t.co/6mpqlpl1q5',
#  'disminuyeron robos lugares hab (-7%) habitados (-2%), robo autos (-20%), etc. qued… https://t.co/4plbzeyqyr',
#  'ayer, hoy mañana saqueo robo justifica robo absolutamente nada, si vamos https://t.co/nh1omytagc',
#  '!!! investiguen robo arcis, 500 millones usd robó https://t.co/bjepjehmro',
#  'robo robo!!! grandes montos, pequeños montos, sol sol hacen millones https://t.co/krkmmjzmhr',
#  'hola! servicios informa juez liberó motochorro robó dos turistas griegos motochorro robó… https://t.co/fgfkvgdfyd',
#  'acreditó probable participación delitos robo vehículo violencia, robo violencia medio… https://t.co/qmphakxjem',
#  'siento punch, robo. robo hicieron inmaculad… https://t.co/acfwlbcgkm',
#  'piden así hará.” combatir corrupción forma equitativa. robo robo mucho, todos… https://t.co/b9prb87dda',
#  'preocupa robo autoritarismo. robo debe analizará mas atrás .desde di… https://t.co/xaygdlfc0k',
#  '2-abrir observatorios robo, así talleres, actividades, asociaciones, etc. ingles robo. https://t.co/blu9v0omgu',
#  'tipo robo robo ivss forrado millones dolares. decomisar dinero devolver… https://t.co/ykxbwbvr9s',
#  'detectives brigada robos sur oriente, logran recuperar vehículo alta gama encargo robo con… https://t.co/ygmqregkgx',
#  '"el robo hugo chávez limitó dinero más, robó venezuela futuro. asaltar poderes… https://t.co/sxnqj6s7pu',
#  'artimaña bien organizada prensa cómplice absoluta trata justificar robo tras robo del… https://t.co/vg615rg2r8',
#  'sra. robo robo así sol millón ladrones coimearon odrebecht tambien quie… https://t.co/kzeco9xxlf',
#  'pdi esclareció robo club unión santo tomé🚔aprehendieron mujer años, robo… https://t.co/ccsgavw5gj',
#  'sinvergüenza piensa mismo robar soles roban 200 mil soles, robo robo. como… https://t.co/cnxc0whig4',
#  'robo robo, hecho linda delito congresistas usufructuaron dinero público deben ser desafo… https://t.co/0llbc4oqke',
#  'solo devuelvan, sino procesados congreso fiscalia, robo robo, lo… https://t.co/pqqxcjiwdk',
#  'robo funcionarios 2006, corrupción 2006, impunidad 2006 robos 2006 má… https://t.co/ibdkrenlzu',
#  '🚓#arica: disminución -29% delito robo lugar habitado; aumentos detenidos 123% robo sorpresa 79% https://t.co/e7eabzzyzt',
#  'audiencia imputativa robo calificado daños 11/09/19 imputó rubén darío echagüe hechos robo https://t.co/5cl15rgkob',
#  'adonde sacará recursos si robo vendrán nuevos robos despuese solo culparan pal… https://t.co/sv8qhtd3dn',
#  '¿fuiste víctima robo negocio? invita marzo taller "un día seguro. robo negoci… https://t.co/nwaww05brl',
#  'cuanto robo vehículos, enero noviembre 2018, cometieron promedio 669.6 robos diarios, mie… https://t.co/37khlzub6d',
#  'si hace corrupción, robo nación, si hace mesías corrupción legal, robo la… https://t.co/dkofua70qs',
#  'ja. gana guita robo. jeta robo. rodillas desesperada suplicando… https://t.co/2kfxvafvon',
#  '4-un hurto robo. alabar, mirar incluso aspirar propiedad micro-robos, solo diferencian grad… https://t.co/5tq2iguxmb',
#  '¿de ríes carapocha? ves partidos equipo. robo athletic robo giron… https://t.co/luqry2m4hm',
#  'tercer robo semana escuela 11. sábado luego dos robos respuesta solidaria maldonado,… https://t.co/xsjpt6fbfm',
#  'veo tal robo. haríamos mal enfocar robo. peor partido simeon… https://t.co/vibnujqta9',
#  'top robo banqueros banex recomienda asalto banco central (2011). film basa robo banco… https://t.co/wqlzfgfwav',
#  'robo changomas hecho robo produjo cerca 23.30 domingo empleados chango… https://t.co/i1phl9m3qu',
#  'realizado denuncias robo vida jamás atendieron. denuncias robo jo… https://t.co/s9njejqykk',
#  '"el robo vehículo mismo periodo gobierno anterior 669.6 robos diario vehículos ah… https://t.co/kktvxmum0o',
#  'top robo banqueros banex recomienda asalto banco central (2011). film basa robo banco… https://t.co/0xh0xvil09',
#  'top condena años años día presidio autor robo retención robo intimida… https://t.co/cknveiotil',
#  'señor robo robo mal, debe devolver dinero sancionar roba si funcionario público peor.… https://t.co/xrhiitd6ld',
#  'top serena condena años años día presidio autor robo retención robo intimida… https://t.co/fvfh8ofnl5',
#  '▪️◾️◼️ reporte robo ◼️◾️▪️ uruapan robos hombres armados robaron camioneta marca toyota, tipo hi… https://t.co/ztshm5pkdi',
#  'robo robo... paso sr. si puede llamar así. pena congreso pe… https://t.co/4kzhaicub9',
#  'robo',
#  'menudo robo',
#  'robo',
#  'asqueroso robo',
#  'saqueo=robo',
#  'robo',
#  '*me robo*',
#  'huele robo',
#  'robo.',
#  'robo',
#  'robo',
#  'vaya robo.',
#  'robo',
#  'robo',
#  'robo',
#  'robo!',
#  'plena luz#',
#  'robo',
#  'robo',
#  'robo mano armada',
#  'puro robo',
#  'robo',
#  'robo palabra armada',
#  'robo',
#  'maldito robo!',
#  'robo',
#  'sigue robo',
#  'cuál robo?',
#  'robo medio',
#  'robo portada',
#  'robo igual-',
#  'jajs robo',
#  'robo tremendo',
#  'naaaaaaaaaaaaaaa robo',
#  'robo',
#  'robo?',
#  'robo-------',
#  'robo biceta',
#  'robo',
#  'robo',
#  'robo!!!',
#  'robo hizo',
#  'robo!',
#  'vulgar robo.',
#  'robo',
#  'robo energía ajena.',
#  'saqueo robo',
#  'robo',
#  'robo',
#  'robo seguro',
#  'robo',
#  'robo igual. (?)',
#  'robo!',
#  'robo más!!',
#  'robo...',
#  'robo??',
#  'jajajajajajajajajajajajajajajajaja vaya robo.',
#  'jajajajajajajajajajajajajajajajaja vaya robo.',
#  'robo',
#  'robo',
#  'robo!',
#  'robo.',
#  'robo.',
#  'robo más!!!!',
#  'robo',
#  'robo',
#  'robo',
#  'robo.',
#  'robo',
#  'robo',
#  'vaya robo jajaja',
#  'robo valladolid.',
#  'noooo... robo',
#  'robo valladolid!!!',
#  'robo!!',
#  'expertos robo.',
#  'robo más!!!!!',
#  'puto robo',
#  '(me robo)',
#  'robo levante',
#  'robo arsenal',
#  'robo penalti',
#  'auténtico robo no?',
#  'menudo puto robo!!!!',
#  'robo',
#  'impuesto robo',
#  'hola robo.',
#  'planean robo nomás',
#  'robo',
#  'favor robo!',
#  'robo',
#  '||te robo frases---',
#  'parece robo',
#  'robo',
#  'robo todos🤧',
#  'robo primero',
#  'robo permiso',
#  'robo equipo',
#  'robo!',
#  'robo',
#  'robo abrazos.',
#  'robo...',
#  'robo demás!!!',
#  'robo !!!!',
#  'robo.',
#  'robo pleno día',
#  'suerte robo.',
#  'robo.',
#  'vergüenza robo monumental....',
#  'medio robo (?) gaaaal',
#  'robo foto',
#  'robo layout',
#  'robo.',
#  'robo',
#  'robo',
#  'comenzó robo',
#  'robo',
#  'robo leones',
#  'no!. robo más!',
#  '"robo hizo"',
#  'robo mano armada....',
#  'robo!',
#  'espero robo',
#  'robo',
#  'terrible robo',
#  'robo grandísimo',
#  'robo bolsonaro',
#  'robo ,bandalismo',
#  'martinelli robo hizo',
#  'robo tremendo',
#  'robo.',
#  'robo... mal',
#  'gran robo',
#  'robo banco?',
#  'ajajaja robo mano armada',
#  'empieza robo...',
#  'robo mitt confirmed',
#  'robo sale mal',
#  'lpm robo gato',
#  'robo peroff',
#  'robo despoblado!',
#  'hizo? robo?',
#  'hoy robo flavia',
#  'uff robo',
#  'robo',
#  'robo mana.',
#  'robo captura puta',
#  'robo',
#  'igual robo.',
#  'es. robo',
#  'robo',
#  'flash robo',
#  'robo 😂😂😂🤣🤣',
#  'robo, gracias!',
#  'vanesa robo vincha',
#  'robo',
#  'robo violacion',
#  'robo:s',
#  'robo...',
#  'robo mas',
#  'robo',
#  'robo',
#  'robo',
#  'robo liar',
#  'fav si robo',
#  'gana robo',
#  'robo',
#  'robo entonces',
#  'robo cambista safado',
#  'robo media imagen',
#  'unidad robo impune (uri)',
#  'mas robo cop..',
#  'robo',
#  'obvio robo',
#  'faltaaaa robo valladolid',
#  'huele robo valladolid',
#  'comience robo',
#  'robo pucela...',
#  'robo, saludos!',
#  'robo dónde?',
#  'robo perro.',
#  'permiso robo',
#  'robo vez',
#  'robo zorrilla.',
#  'robo',
#  'robo girona',
#  'robo tmb',
#  'quieta robo boroliro',
#  'robo foto...',
#  'resaca robo.',
#  'suscribo, robo.',
#  'gran robo',
#  'increíble robo',
#  '¿otro robo levante?',
#  'ganan robo.',
#  'robo descarado londres',
#  'robo united',
#  'buen robo',
#  'eso? robo?',
#  'robo',
#  'vaya robo girona.',
#  'sensibilidad robo',
#  'literal, inseguridad robo',
#  'seguro robo nada!!???',
#  'robo',
#  'visto robo',
#  'ansiedad robo',
#  'robo identidad?🤔',
#  'robo 27000',
#  'intensidad robo',
#  'adrenalina robo...',
#  'robo aaa',
#  'interes robo',
#  'robo',
#  'cansancio robo',
#  'robo kler',
#  'sensibilidad robo',
#  'medicina robo novia',
#  'intensidad robo',
#  'autoestima robo!',
#  'mercantil robo pistola',
#  'robo dónde sea.',
#  'autocontradiccion robo',
#  'gusta. robo',
#  'carlos robo...andaro',
#  'altura robo',
#  'dependencia robo',
#  'ansiedad robo.',
#  'decontruccion robo!',
#  'robo. puedo?',
#  'metas robo',
#  'robo meme',
#  'kinks robo.',
#  'robo',
#  'víctima robo',
#  'sueño robo',
#  'emoción robo',
#  'robo compañeros',
#  'papada robo',
#  'jajajajaja robo!',
#  'mina robo lugar',
#  'falsedad robo',
#  'insensibilidad robo',
#  'robo? penalazos',
#  'maldito robo !!! abusadores 😡😡😡😡😡',
#  'puto robo',
#  'robo',
#  '“prioridades” robo.',
#  'organizamos robo?',
#  'seca robo',
#  'moral robo',
#  'robo despoblado.',
#  'década robo',
#  'exelente robo',
#  'premenstrualidad robo',
#  'robo vídeos !!!',
#  'sensibilidad robo',
#  'robo infinito amor',
#  'empate robo',
#  'construcciones robo',
#  'desinterés robo',
#  'robo',
#  'seguridad robo',
#  'robo mano armada 😡😡😡',
#  'inseguridad robo',
#  'puedes robo cantenido',
#  'robo perdón',
#  'robo',
#  'robo imagen',
#  'originalidad robo',
#  'confundir? robo caño',
#  'dolor robo',
#  'penal, empezó robo',
#  'falsedad robo',
#  'dignidad robo',
#  'robo mano armada 🤷🏼\u200d♂️',
#  'excitación robo',
#  'saqueo, robo !!!',
#  'indirectas robo.',
#  'interes robo',
#  'robo partido maaan',
#  'robo tweet!',
#  'bueno robo',
#  'cuanta plata robo????',
#  '😂😂😂 robo',
#  'falsedad robo.',
#  'voy robo asies',
#  'robo 😂😂😂',
#  'redactada robo',
#  'mal humor robo',
#  'dependencia instagram robo',
#  'robo, vergonzoso',
#  'convinaciòn robo',
#  'nervios robo',
#  'robo?, mamita!!!!',
#  'ganas robo',
#  'robo',
#  '"interés" robo',
#  'sensibilidad robo',
#  'utilización robo',
#  'sensibilidad robo',
#  'jajaja robo!',
#  'robo',
#  'robo tan asqueroso',
#  'robo autos?',
#  'combinaciones robo',
#  'robo vivir asi',
#  'robo 😂😂😂',
#  'convinaciones robo',
#  'robo ...',
#  'estres robo',
#  'bullying robo',
#  'aiñ robo!',
#  'interes robo',
#  'robo ,así simple',
#  'resentimiento robo',
#  'robo',
#  'toda razón..un robo',
#  'mario &gt; chibi-robo!',
#  'celos robo.',
#  'así robo...mamelucoo',
#  'saqueo robo, fin.',
#  'viveza ..es robo..',
#  'machismo robo!',
#  'indirecta robo',
#  'resentimiento robo',
#  'facha robo',
#  '¿quien robo empanada?',
#  '??????? densidad robo',
#  'robo',
#  'intensidad robo',
#  'amigas robo',
#  'interés robo',
#  'delicadeza robo.',
#  'robo gigolo exce🎶🎶',
#  'uvita robo',
#  'robo curandera',
#  'saqueo robo...',
#  'hipocresía robo',
#  'viene robo',
#  'robo prro',
#  'robo',
#  'robo geniol',
#  'jajajajaja robo',
#  'jajajajaja robo',
#  'patrocinando robo',
#  'llama robo allanamiento.',
#  'robo jadue?',
#  'robo branding',
#  'robo descarado.',
#  'robo, merecía',
#  'si, comparto, robo',
#  'robo, compermiso',
#  'andares! robo...',
#  'intensidad robo.',
#  'asi comida robo.',
#  'robo imagen',
#  'cobardía robo',
#  'pongo máscara robo',
#  'robo piola!!!',
#  'alto robo fue...',
#  'inseguridades robo',
#  'falsedaddd. robo',
#  'amor robo',
#  'siga robo',
#  'susceptibilidad robo',
#  'saqueo, robo',
#  'machismo robo amigaaaaaa',
#  'robo',
#  'interés robo',
#  'vandalismo robo....',
#  'envidia robo',
#  'robo historia',
#  'robo',
#  'cara amigo robo',
#  'interés robo',
#  'grrrrrr, basta robo.',
#  'robo 105🤔',
#  'robo jajajaja',
#  'corto vaya robo :(((((',
#  'ganas robo',
#  'robo sensibilidad amiga',
#  'confianza robo',
#  'intensidad robo',
#  'robo hilo',
#  'ajajajaajajajajaj robo',
#  'originalidad,no robo',
#  'jajajaja robo',
#  'primer robo noche',
#  'menudo robo chaval',
#  'robo partidos',
#  'que? robo imagenes',
#  'si robo tweets román',
#  'hipocresía robo',
#  'pesimismo robo',
#  'robo',
#  'unas divas robo',
#  'robo memes',
#  'robo 😂😂😂',
#  'robo aficionados valla.',
#  'robo grande visto.',
#  'robo, robas.',
#  'amor robo',
#  'robo inexplicable',
#  'robo rizos',
#  'robo gero',
#  'ignorada robo',
#  'robo demasiado tipo.',
#  'mmmm negri, robo',
#  'ansiedad robo',
#  'personalidad robo',
#  'robo chiste.',
#  'dólares eso? tremendo robo',
#  'robo delfino ayer',
#  'robo devuelvo',
#  'robo meme',
#  'perro robo mas!!',
#  'contractura robo.',
#  'ataco robo',
#  'robo',
#  'robo historia..',
#  'permitame robo',
#  'robo presidenciales.',
#  'elizabeth robo',
#  'robo',
#  'robo',
#  'intensidad robo..',
#  'actitud robo.',
#  'compañerismo robo',
#  'dignidad robo',
#  'autoestima robo',
#  'jaaaa cuanto robo',
#  'desinterés robo',
#  'robo gente!',
#  'cualquier cosa incluye robo',
#  'bajón robo',
#  'robo siendo descomunal.',
#  'pues robo más.',
#  'inmadurez robo',
#  'tremendo robo valladolid',
#  'robo despoblado valladolid...',
#  'loco ...un robo',
#  'robo guante blanco',
#  'primer robo partido jojojo',
#  'fkdkdkekxkdkkssk aiññññññ robo',
#  'pronto empezamos robo',
#  'robo claramente',
#  'obvio robo 😡😡😡',
#  'brillante. robo.',
#  '¿por robo tuits?',
#  'intensidad robo',
#  'robo américa',
#  'robo naco',
#  'robo maldito',
#  'robo.... olé',
#  'jajaja robo',
#  'robo moto',
#  'superación robo',
#  'robo levante',
#  'madre robo',
#  'intensidad robo',
#  'robo!! vez',
#  'robo descarado londres jaja',
#  'alto robo hijos puta',
#  'medio robo united',
#  'emociona robo united',
#  'riquísimo robo arsenal',
#  'robo arsenal. mamita.',
#  'resfrío robo.',
#  'acidez robo',
#  'confianza robo',
#  'conoces robo flip ???',
#  'intensidad robo',
#  'trauma robo',
#  'robo',
#  'robo mamita',
#  'tremendo robo, falton patricl roberts',
#  '...incluye sidral robo!',
#  'robo chocolatinas oxxo',
#  'pura mierda....grupo robo',
#  'misoginia robo',
#  'jajaja robo?',
#  'justifica robo publico?',
#  'robo imagen',
#  'mala suerte robo',
#  'contractura robo martaaa!',
#  'insegurudad robo amigo',
#  'ésta gripe robo, amigo',
#  'armoso!!! ... robo andy',
#  'extrañar robo',
#  'suerte robo solange',
#  'robo qlo',
#  'robo meme',
#  'inseguridad robo amiga...',
#  'robo amigo',
#  'rata robo millones',
#  'robo marte, mercurio',
#  'robo uno.',
#  'robo!!',
#  'robo foto jaja',
#  'canelita robo bolsa monedas',
#  'toxicidad robo hermano',
#  'robo también...!!!',
#  'jajajajaa tocs robo',
#  'robo permisito',
#  'lesbianismo robo jajajajajaja',
#  'robo siglo',
#  'robo vengo baratico',
#  'no, robo consumo adentro',
#  'amiga aburriendo robo',
#  'chiquito robo',
#  'hipocresia robo',
#  'callate robo',
#  'playback robo jajajajaj',
#  'alguien robo pagina',
#  'douuu robo primero',
#  'doble moral robo',
#  'tibieza robo amigo',
#  'concepto. robo.',
#  'jajajajaja robo',
#  'robo identidades ahora mira😁',
#  'contradicción robo mabeeeel',
#  'robo foto',
#  'después robo pkdora',
#  'suerte robo jajajaja',
#  'jajajaja originalidad robo',
#  'autuestima robo amiga',
#  'infop, gran robo cachireco!!',
#  'doble moral robo',
#  'sueño beso robo..',
#  'mala suerte robo',
#  'jajajajaja gato robo atención',
#  'robo comonuna catedral',
#  'caradures robo!',
#  'intensidad robo shabri',
#  'puto robo',
#  'vil robo https://t.co/xzdzk8hpeo',
#  'mejor. me. robo yo.. atte bronci',
#  'stalkeada robo mono',
#  'pongo máscara robo',
#  'parte robo?',
#  '¿quién robo inocencia?',
#  'fua esquivada robo',
#  'robo máscara gracias',
#  'ésta ansiedad robo',
#  'contradicciones robo',
#  'micro robo señoras',
#  'si robo parejo',
#  'robo suerte',
#  'intensidad robo',
#  'reflexión robo amigaaaa',
#  'mas robo datos (?)',
#  'entendí, justificas impunidad robo,?',
#  'intensidad robo magui',
#  'boluudaaa, inseguridades robo.',
#  'mmm idiotez robo',
#  'densidad robo amiga',
#  'organización robo',
#  '-oye buba espuma robo idea...',
#  'gramática robo amiga.',
#  'melancolía robo',
#  'nervios robo',
#  'cara robo',
#  'celos robo amego',
#  'intensidad manejo robo',
#  'embole robo eh...',
#  'tiren piropos lindos así robo',
#  'contractura robo',
#  'jajsjajaau encanto robo',
#  'resentimiento robo pibito\U0001f92d',
#  'maldad robo',
#  'suerte robo hmno',
#  'robo ceja',
#  'tan diablo robo',
#  'bue redacción robo',
#  'blindaje robo amigue.',
#  'robo ya,',
#  'marketing robo',
#  'buenna bipolaridad robo',
#  'suerte robo',
#  'crisis robo',
#  'resentimiendo kpo, robo',
#  'trabajo robo',
#  'sinceridad robo',
#  'estereotipos robo amiga',
#  'robo!',
#  'federico robo corazón',
#  'robo derechistas sinverguenzas',
#  'hipocresía robo amigue',
#  'calidad imagen robo',
#  'robo meme gracias',
#  'robo gobierno',
#  'vida robo',
#  'robo primer gol',
#  'bue visto robo',
#  'redacción...no robo',
#  'alguien robo pole',
#  'pérdida imbécil, robo',
#  'suerte robo.',
#  'loca robo corazon',
#  'robo meme, permiso',
#  'manokkkkkkkkkjjkjkjkkkkkk robo buceta chorandokkjkkkjkk',
#  'nervios robo...😰😰',
#  'adivinen robo',
#  'traumatismo robo 😫😤\U0001f92f\U0001f92f\U0001f92f',
#  'robo joh',
#  'robo nombre',
#  'inmadurez robo hermano',
#  'alguien robo datos feis',
#  'desprecio robo jamás',
#  'robo solo así ganan',
#  'resentimiento robo hno',
#  'interés robo amiga',
#  'robo siglo.',
#  'jajajaja buitreadas robo',
#  'bue prioridades robo',
#  'robo pedo',
#  'jajaj robo 5-1 no?',
#  'códigos robo 🙄🙄🤣',
#  'fracaso robo',
#  'humor negro, robo',
#  'entonces drogo robo mato piñas',
#  'mae loca robo',
#  'mmm mentalidad robo',
#  'completo robo..... lacras deporte',
#  'sigue siendo robo, ash',
#  'retórica robo.',
#  'toxicidad robo amiga',
#  'robo banco seguro',
#  'mala onda robo',
#  'paciencia robo',
#  'saqueo robo',
#  'robo finquita desgraciado',
#  'si verdad robo',
#  'levante robo',
#  'robo platense van...',
#  'villereada robo man',
#  '*en dos dias robo”',
#  'ignorancia robo amiga.',
#  'petróleo cuba! robo.',
#  'robo sigue',
#  'robo exagerado.',
#  'lógica robo amiga',
#  'desinteres robo.😂',
#  'abstinencia robo amigo',
#  'autoestima manejo, robo',
#  'puesto robo jjajaja',
#  'encanto robo',
#  'intensidad robo julieta',
#  'ansiedad robo.',
#  'robo asolapado..... devuelvan robado',
#  'robo todas luces!!!',
#  'robo pal face.',
#  'mí, impuesto robo.',
#  'masculinidad frágil robo',
#  'maldaaad robo jaja',
#  'justificar robo....',
#  'todas luces, robo base',
#  'bonita foto robo',
#  'emputado uro robo sala!',
#  'vergüenza ajena robo',
#  'gustó, robo',
#  'doble moral robo',
#  'calidad robo',
#  'enserio robo eso?',
#  'robo?',
#  'llama robo.....',
#  'ansiedad robo',
#  'robo meme.🤣',
#  'robo siglo',
#  'robo. adios.',
#  'permiso robo',
#  'omo robo',
#  'comodidad robo pelotuda',
#  'robo comentario...jaja.',
#  'humedad robo',
#  'redaccion robo',
#  'costando robo..',
#  'caos total, vandalismo, robo.',
#  'lucas peaje! robo',
#  'superación robo',
#  'creo robo',
#  'rioboo robo vez más.',
#  'inseguridad robo amiga...',
#  'meme robo jajajaja',
#  'intensidad robo hna',
#  'pewe ser robo secreto',
#  'español robo amigoooooo',
#  'jaja robo',
#  'culo sucio robo',
#  'robaré tweets, mejor robo besos.',
#  'robaré tweets, mejor robo besos.',
#  'madurez robo amigo',
#  'robo loot',
#  'mmmm inseguridad robo',
#  'traducción robo',
#  'problemas robo',
#  'ansiedad robo \U0001f92f💙💜',
#  'memes robo',
#  'efectos robo amigo',
#  'suerte robo',
#  'encanto robo',
#  'robo barón',
#  'furious robo barón semana',
#  'robo, pido prestado',
#  'hombre robo corazón',
#  'celos robo',
#  'humedad robo amigo',
#  'autoestima robo bro',
#  'intensidad robo jajajaj',
#  'robo sabes chau',
#  'egoísmo robo amigo',
#  'desesperación robo amigo',
#  'robo meme ahre.',
#  'falsedad robo amiga.',
#  'penal robo abal',
#  'robo frases, siguen prefiriendo\U0001f92d',
#  'xddd robo',
#  'gordo valor, robo.',
#  'reputación robo amigo',
#  'robo gigante https://t.co/ialzmmqbp7',
#  'vaya robo pobre álvaro',
#  'entiendo robo álvaro',
#  'robo nadie okei😡😡😡😡😡😡😡😡😡😡',
#  'orgullo robo',
#  'toxicidad robo!',
#  'felicidad robo',
#  'originalidad robo',
#  'encantó robo',
#  'racing robo punto capo',
#  'ida robo brutal',
#  'no, sido robo mano armada.',
#  "sa' bola amigo, robo",
#  'amor robo',
#  'robo meme lo100to',
#  'viene robo',
#  'robo sido... asqueroso.',
#  'ambivalencia robo agustín',
#  'robo mucha piña',
#  'honestidad robo',
#  'mala suerte robo',
#  'jajajajaja retraso robo',
#  'mal humor robo',
#  'robo, compañero',
#  'menudo robo rosaleda señores.',
#  'avala "robo hormiga"',
#  'zonambulismo robo',
#  'suerte si robo',
#  'robo pinturas',
#  '¿perdón? robo descarado.',
#  'señor, simple robo, codicia',
#  'pensé nunca vivir semejante robo!',
#  'si robo',
#  'audacia robo',
#  'rateros!!es robo asolapado.',
#  'variar justificando robo',
#  'sueño beso robo',
#  'interés robo',
#  'robo combustible.',
#  'robo mujer????',
#  'injusto completo robo',
#  'robo riverita.',
#  'robaselos aunque seria robo',
#  'robo',
#  'desinterés robo bro',
#  'baja autoestima robo',
#  'robo carnaval',
#  'robo',
#  'ah, entonces robo pues.',
#  'pillaje...robo',
#  'fanatismo oculto robo!!!!!!',
#  'asociemos robo',
#  'amiga robo !!!',
#  'planeado robo banco!',
#  'robo legal tipo pirámide',
#  'robo',
#  'mayor robo dortmund.',
#  'vagancia robo',
#  'suerte robo',
#  'robo besito',
#  'robo plata peñarol',
#  'ganas robo',
#  'messi laburo...el robo',
#  'espero sino vaya robo',
#  'mala leche robo!',
#  'suerte robo eh....',
#  'si robo beso!',
#  'robo korason ahre',
#  'inseguridad robo amiga',
#  'inestabilidad emocional robo',
#  'humildad robo',
#  'aunque robo users',
#  'truenos robo mabeeel👀',
#  'ése interés robo',
#  '😂😂tuitazo... deja robo!',
#  'robo museo carondelet.',
#  'famoso robo "hormiga"',
#  'robo sigue seguirá siempre.',
#  'robo puto madriz baboso',
#  'opinas robo',
#  'resaca robo amiga🤢',
#  'robo descarado zorrilla! aúpa pucela!',
#  'dónde robo?',
#  'toxicidad robo',
#  'menudo robo dais pena',
#  'penal valladolid? mamita robo!',
#  'resaca robo amiga',
#  'robo meme gracias',
#  'desconfianza robo amiguita',
#  'organización robo amigo',
#  'vamos empieza robo valladolid.',
#  'ay madre robo',
#  'robe robo :).',
#  'venezuela robo rayo zeus',
#  'lloré, sensibilidad robo',
#  'robo moto',
#  'morbo robo. asco.',
#  'chamuyo robo amigo😂',
#  'boludes mental robo',
#  'robo, asesinatos, impunidad, gollerias... etc',
#  'indirectas robo... activá!',
#  'dignidad robo',
#  'estafa robo nacional...',
#  'semana mas. puto robo.',
#  'cuernos robo amixxx',
#  'interés robo hno',
#  'robo mano armada',
#  'relaxion toxica robo',
#  'impuestos robo.',
#  'lógica robo',
#  'voy robo',
#  'hembrismo robo amiga',
#  'resaca robo',
#  'lloré, sensibilidad robo',
#  'robo camisa 😂😂😂',
#  'autoestima robo jajajajajaja',
#  'giane robo videos',
#  'robo moto',
#  'kirchenrismo robo no?',
#  'funk robo corazón jajaja💞',
#  'nanana dignidad robo',
#  'dios densidad robo',
#  'inestabilidad emocional robo...',
#  'deseo inconsciente robo.',
#  'robo funda movil',
#  'doble moral robo amigue',
#  'robo bio!',
#  'jajajajaja permiso robo tuit',
#  'ganas hablar, robo.',
#  'resentimiento robo jajajajajajaj',
#  ...]

# %%
datos_limp = [re.sub(r'http\S+', '', x) for x in datos_limp] # Eliminamos las URL
datos_limp = [''.join(c for c in x if c not in string.punctuation) for x in datos_limp] # Eliminamos signos de puntuación
datos_limp = [''.join(c for c in x if c not in '0123456789') for x in datos_limp] #Eliminamos los numeros
datos_limp = [' '.join(x.split()) for x in datos_limp] # Eliminar espacios en blanco y separadores extras

# %%
#datos_limp = datos_limp.encode('ascii', 'ignore').decode('ascii')
datos_limp = [' '.join(a.encode('ascii', 'ignore').decode('ascii') for a in x.split()) for x in datos_limp]
datos_limp = [x for x in datos_limp if len(x) > 5]
datos_limp
# Out:
# ['robo robo gran robo',
#  'robo robo',
#  'robo robo robo asco da real madrid',
#  'robo plantel educativo robo transente robo cuentahabiente robo repartidor ',
#  'robo robo robo familia ladrones',
#  'robo robo ratero',
#  'robo robo',
#  'robo robo',
#  'si robo racing comio robo mas grande bernabeu mas robo baile',
#  'no excepto opciones robo energa elctrica robo robo si codeca ladrones',
#  'menos foros seguridad robos trabajorobo casas hijas robo telfono cel',
#  'robe rena robo forest robo haru vez robo ranito',
#  'robe rena robo forest robo haru vez robo ranito',
#  'robo descarado visca robo farca',
#  'saqueo robo robo delito',
#  'as sol robo robo',
#  'as solrobo robo',
#  'robo robos',
#  'robo pena robo jijiji',
#  'rob jajajajajajaja poesa robo amiga',
#  'saqueo robo justifica robo',
#  'as sol robo robo',
#  'basta robos llama robo',
#  'robo mas robo',
#  'miren robo robo',
#  'temporadas robo robo amiga',
#  'chavismo rt saqueo robo robo delito',
#  'veo venir hoy va ser robo tras robo',
#  'da mano mano hombro hombro robo robo',
#  'robo bien uso rob madre',
#  'soles solesrobo robo',
#  'robo aqu robo all pinto colores',
#  'usted funes hizo solo robo robo mundo sabe',
#  'desgraciados entienden robo robo aunque sol',
#  'serio robo nada fijate robo gobierno corrupto',
#  'peor robo puede ser objeto robo tiempo',
#  'alguien robo feat wisin amp nacho sebastian yatra alguien rob feat wisin amp nacho single',
#  'robo jajaja frase robo espaa canalla puede esperar cosa',
#  'protege robos menos robo jajaja',
#  'mismas fidel robo nacionalizacin robo',
#  'totalmente acuerdo contigo arquera robos robos buenas acciones ellos',
#  'lasallista significa robo cosas bueno si robo cosas lasallista',
#  'gran robo pblico comenz sept parado robo plus transicin',
#  'intensidad manejamos familia robo ameo mentira robo mil vidas mas',
#  'crees gan escuchas ftbol radio robo friend puro robo',
#  'robo cuenta l pueblo menos politicos robo mal',
#  'robo hables difundas estupideces robo empate castao gan dos puntos',
#  'policiaecuador detiene organizacin delictiva dedicada robo accesorios vehculos robo personas',
#  'hno cualquiera cristina cualquiera nadie puede decir robo abismal robo',
#  'robo no miren ete degracimao rob carro',
#  'seria robo robos digo colmo colmos',
#  'atencin continuan robos ciudadelas nueva modalidad robo alquilan departamentos dentro urbanizaciones',
#  'robo tras robo cada eliminatorias zidane madrid',
#  'robo quedar impune viene referendo revocatorio hacer trizas robo colombianos',
#  'sinnimo narcochavismocastrista destruccin robo muerte destruccin robo muerte destru',
#  'detienen hombre robo violencia cuentahabiente',
#  'claro claro no violacion violacion robo tampoco robo',
#  'pronuncia frase robo hizo desea practicar robo hbito criminal',
#  'arcos vallarta constante robo mano armada robo casa habitacin negoci',
#  'descaro robo institucionalizado izquierda estado robo',
#  'mojonnncero inversion robo total quitale malpica flores maria gabriela chavez robo mas descarado nacion',
#  'tipo robo helicptero robo armamento militar amenazo muerte presidente',
#  'patrullero evit robo casino luego rob plata salv delincuentes',
#  'vuelve monumental despus robo libertadores gallardo quiere hablar rbitrovolver robo',
#  'patrullero evit robo casino luego rob plata salv delincuentes',
#  'cuanto robo megacorrupto narcoindultador robo ams presidentes solo superado po',
#  'robo robo usted voto salaverry presidente ahora dice la',
#  'ascenso llegar robo tras robo cada semana callarse',
#  'hoy escuela compr caf mediano salia nana robo robo encima horrible',
#  'minuto partido llego internet robo robo luego yoigo',
#  'hagas parecer supuesto si robo robo harto dir',
#  'pblicas robo si tal cerrada porter ganaba empate titularlorobo ao',
#  'mismo rob rafael ramrez tuerto andrade panas suyos tipo robo',
#  'joda vice riber manejando siga robo siga robo atraco fantasmas',
#  'triste ver robo hambre va preso robo fugarla impune',
#  'robo hoy detiene robo vehculos celaya',
#  'dictador robo plebiscito error historico robo',
#  'vos das mas robos coparticipacinfondo sojero aportes truchoslavado dinerorobo identidad',
#  'viejo huevon robo robo as robes sol soles idea viejo cabro',
#  'robo grado tentativa periodista procesaron autores robo periodista romina mariel za',
#  'podemos decir robo robo menos final dos robaron caigamos',
#  'anunciando intento robo robo mira mientras herido crescenti',
#  'esque cd censura robo cmara ahora robo celular',
#  'robo invernadero asociacin conrazones guarda',
#  'mal reparto robo robo cada da salen casos pasa avisan escapan',
#  'robo hicieron lyon robo tercer gol del',
#  'nesecidad igual paro miedo robo siempre uso cicloruta miedo robos carros',
#  'cansados robos asaltos vecinos barrio cuarto detuvieron amarraron sujeto robo una',
#  'robo auto robos transentes reportan vigilancia hro',
#  'argumenta gobierno pea robo robo dudas cambio forma gobernar  digo par',
#  'saqueo robo agravantes posible robo violencia hurto sin violencia accin apod',
#  'robo personas robo bancos muestran tendencia creciente acuerdo comportamiento deli',
#  'presunto robo transente arrestado sujeto apodado el malilla presunto robo telfono celu',
#  'robo si robo ilusin derecho generacin intentando ser desgracia persona',
#  'detienen sujeto tentativa robo domicilio tentativa robo domicilio detenido sujet',
#  'disculpas si sono lecciones llamaste robo robo',
#  'razn quitaron robo hidrocarburos cerrando llaves quitaran robo',
#  'robos parte funcionarios confianza gobernador robo leche desnutridos toneladas cr',
#  'se redujo robo hidrocarburos pues iba bajar robo si hay gracias estup',
#  'verdad flipo robo tras robo inviten programa encima',
#  'presidente iviss carlos rotondaro robo millones robo vidas actu solo mu',
#  'principio avisar misma comisara denunci robo si robo denunci fail',
#  'alto robo vehculosprevenir puede frustrar robo invitamos hacer conciencia tomar medidas pu',
#  'botar cualquir peronista kirchnerista seguir robo tonses solucin fasil pagar impuestos acaba rob',
#  'cambio idea disimular todas luces solo robo robo',
#  'delito comete robo casa habitacin seguido robo vehculos autopartes',
#  'delincuentes slo hicieron robo violencia sino dicho robo motivado odio hacia perso',
#  'saquear tiendas comida justifica robo robo ahora tener hambre derecho ir robar propied',
#  'nahh llegaron final robo ganaron robo aplic reglamento manera injusta',
#  'disminuyeron robos lugares hab habitados robo autos etc qued',
#  'ayer hoy maana saqueo robo justifica robo absolutamente nada si vamos',
#  'investiguen robo arcis millones usd rob',
#  'robo robo grandes montos pequeos montos sol sol hacen millones',
#  'hola servicios informa juez liber motochorro rob dos turistas griegos motochorro rob',
#  'acredit probable participacin delitos robo vehculo violencia robo violencia medio',
#  'siento punch robo robo hicieron inmaculad',
#  'piden as har combatir corrupcin forma equitativa robo robo mucho todos',
#  'preocupa robo autoritarismo robo debe analizar mas atrs desde di',
#  'abrir observatorios robo as talleres actividades asociaciones etc ingles robo',
#  'tipo robo robo ivss forrado millones dolares decomisar dinero devolver',
#  'detectives brigada robos sur oriente logran recuperar vehculo alta gama encargo robo con',
#  'el robo hugo chvez limit dinero ms rob venezuela futuro asaltar poderes',
#  'artimaa bien organizada prensa cmplice absoluta trata justificar robo tras robo del',
#  'sra robo robo as sol milln ladrones coimearon odrebecht tambien quie',
#  'pdi esclareci robo club unin santo tomaprehendieron mujer aos robo',
#  'sinvergenza piensa mismo robar soles roban mil soles robo robo como',
#  'robo robo hecho linda delito congresistas usufructuaron dinero pblico deben ser desafo',
#  'solo devuelvan sino procesados congreso fiscalia robo robo lo',
#  'robo funcionarios corrupcin impunidad robos m',
#  'arica disminucin delito robo lugar habitado aumentos detenidos robo sorpresa',
#  'audiencia imputativa robo calificado daos imput rubn daro echage hechos robo',
#  'adonde sacar recursos si robo vendrn nuevos robos despuese solo culparan pal',
#  'fuiste vctima robo negocio invita marzo taller un da seguro robo negoci',
#  'cuanto robo vehculos enero noviembre cometieron promedio robos diarios mie',
#  'si hace corrupcin robo nacin si hace mesas corrupcin legal robo la',
#  'ja gana guita robo jeta robo rodillas desesperada suplicando',
#  'un hurto robo alabar mirar incluso aspirar propiedad microrobos solo diferencian grad',
#  'de res carapocha ves partidos equipo robo athletic robo giron',
#  'tercer robo semana escuela sbado luego dos robos respuesta solidaria maldonado',
#  'veo tal robo haramos mal enfocar robo peor partido simeon',
#  'top robo banqueros banex recomienda asalto banco central film basa robo banco',
#  'robo changomas hecho robo produjo cerca domingo empleados chango',
#  'realizado denuncias robo vida jams atendieron denuncias robo jo',
#  'el robo vehculo mismo periodo gobierno anterior robos diario vehculos ah',
#  'top robo banqueros banex recomienda asalto banco central film basa robo banco',
#  'top condena aos aos da presidio autor robo retencin robo intimida',
#  'seor robo robo mal debe devolver dinero sancionar roba si funcionario pblico peor',
#  'top serena condena aos aos da presidio autor robo retencin robo intimida',
#  ' reporte robo  uruapan robos hombres armados robaron camioneta marca toyota tipo hi',
#  'robo robo paso sr si puede llamar as pena congreso pe',
#  'menudo robo',
#  'asqueroso robo',
#  'saqueorobo',
#  'me robo',
#  'huele robo',
#  'vaya robo',
#  'plena luz',
#  'robo mano armada',
#  'puro robo',
#  'robo palabra armada',
#  'maldito robo',
#  'sigue robo',
#  'cul robo',
#  'robo medio',
#  'robo portada',
#  'robo igual',
#  'jajs robo',
#  'robo tremendo',
#  'naaaaaaaaaaaaaaa robo',
#  'robo biceta',
#  'robo hizo',
#  'vulgar robo',
#  'robo energa ajena',
#  'saqueo robo',
#  'robo seguro',
#  'robo igual',
#  'robo ms',
#  'jajajajajajajajajajajajajajajajaja vaya robo',
#  'jajajajajajajajajajajajajajajajaja vaya robo',
#  'robo ms',
#  'vaya robo jajaja',
#  'robo valladolid',
#  'noooo robo',
#  'robo valladolid',
#  'expertos robo',
#  'robo ms',
#  'puto robo',
#  'me robo',
#  'robo levante',
#  'robo arsenal',
#  'robo penalti',
#  'autntico robo no',
#  'menudo puto robo',
#  'impuesto robo',
#  'hola robo',
#  'planean robo noms',
#  'favor robo',
#  'te robo frases',
#  'parece robo',
#  'robo todos',
#  'robo primero',
#  'robo permiso',
#  'robo equipo',
#  'robo abrazos',
#  'robo dems',
#  'robo pleno da',
#  'suerte robo',
#  'vergenza robo monumental',
#  'medio robo gaaaal',
#  'robo foto',
#  'robo layout',
#  'comenz robo',
#  'robo leones',
#  'no robo ms',
#  'robo hizo',
#  'robo mano armada',
#  'espero robo',
#  'terrible robo',
#  'robo grandsimo',
#  'robo bolsonaro',
#  'robo bandalismo',
#  'martinelli robo hizo',
#  'robo tremendo',
#  'robo mal',
#  'gran robo',
#  'robo banco',
#  'ajajaja robo mano armada',
#  'empieza robo',
#  'robo mitt confirmed',
#  'robo sale mal',
#  'lpm robo gato',
#  'robo peroff',
#  'robo despoblado',
#  'hizo robo',
#  'hoy robo flavia',
#  'uff robo',
#  'robo mana',
#  'robo captura puta',
#  'igual robo',
#  'es robo',
#  'flash robo',
#  'robo gracias',
#  'vanesa robo vincha',
#  'robo violacion',
#  'robo mas',
#  'robo liar',
#  'fav si robo',
#  'gana robo',
#  'robo entonces',
#  'robo cambista safado',
#  'robo media imagen',
#  'unidad robo impune uri',
#  'mas robo cop',
#  'obvio robo',
#  'faltaaaa robo valladolid',
#  'huele robo valladolid',
#  'comience robo',
#  'robo pucela',
#  'robo saludos',
#  'robo dnde',
#  'robo perro',
#  'permiso robo',
#  'robo vez',
#  'robo zorrilla',
#  'robo girona',
#  'robo tmb',
#  'quieta robo boroliro',
#  'robo foto',
#  'resaca robo',
#  'suscribo robo',
#  'gran robo',
#  'increble robo',
#  'otro robo levante',
#  'ganan robo',
#  'robo descarado londres',
#  'robo united',
#  'buen robo',
#  'eso robo',
#  'vaya robo girona',
#  'sensibilidad robo',
#  'literal inseguridad robo',
#  'seguro robo nada',
#  'visto robo',
#  'ansiedad robo',
#  'robo identidad',
#  'intensidad robo',
#  'adrenalina robo',
#  'robo aaa',
#  'interes robo',
#  'cansancio robo',
#  'robo kler',
#  'sensibilidad robo',
#  'medicina robo novia',
#  'intensidad robo',
#  'autoestima robo',
#  'mercantil robo pistola',
#  'robo dnde sea',
#  'autocontradiccion robo',
#  'gusta robo',
#  'carlos roboandaro',
#  'altura robo',
#  'dependencia robo',
#  'ansiedad robo',
#  'decontruccion robo',
#  'robo puedo',
#  'metas robo',
#  'robo meme',
#  'kinks robo',
#  'vctima robo',
#  'sueo robo',
#  'emocin robo',
#  'robo compaeros',
#  'papada robo',
#  'jajajajaja robo',
#  'mina robo lugar',
#  'falsedad robo',
#  'insensibilidad robo',
#  'robo penalazos',
#  'maldito robo abusadores ',
#  'puto robo',
#  'prioridades robo',
#  'organizamos robo',
#  'seca robo',
#  'moral robo',
#  'robo despoblado',
#  'dcada robo',
#  'exelente robo',
#  'premenstrualidad robo',
#  'robo vdeos',
#  'sensibilidad robo',
#  'robo infinito amor',
#  'empate robo',
#  'construcciones robo',
#  'desinters robo',
#  'seguridad robo',
#  'robo mano armada ',
#  'inseguridad robo',
#  'puedes robo cantenido',
#  'robo perdn',
#  'robo imagen',
#  'originalidad robo',
#  'confundir robo cao',
#  'dolor robo',
#  'penal empez robo',
#  'falsedad robo',
#  'dignidad robo',
#  'robo mano armada ',
#  'excitacin robo',
#  'saqueo robo',
#  'indirectas robo',
#  'interes robo',
#  'robo partido maaan',
#  'robo tweet',
#  'bueno robo',
#  'cuanta plata robo',
#  'falsedad robo',
#  'voy robo asies',
#  'redactada robo',
#  'mal humor robo',
#  'dependencia instagram robo',
#  'robo vergonzoso',
#  'convinacin robo',
#  'nervios robo',
#  'robo mamita',
#  'ganas robo',
#  'inters robo',
#  'sensibilidad robo',
#  'utilizacin robo',
#  'sensibilidad robo',
#  'jajaja robo',
#  'robo tan asqueroso',
#  'robo autos',
#  'combinaciones robo',
#  'robo vivir asi',
#  'convinaciones robo',
#  'estres robo',
#  'bullying robo',
#  'ai robo',
#  'interes robo',
#  'robo as simple',
#  'resentimiento robo',
#  'toda raznun robo',
#  'mario gt chibirobo',
#  'celos robo',
#  'as robomamelucoo',
#  'saqueo robo fin',
#  'viveza es robo',
#  'machismo robo',
#  'indirecta robo',
#  'resentimiento robo',
#  'facha robo',
#  'quien robo empanada',
#  'densidad robo',
#  'intensidad robo',
#  'amigas robo',
#  'inters robo',
#  'delicadeza robo',
#  'robo gigolo exce',
#  'uvita robo',
#  'robo curandera',
#  'saqueo robo',
#  'hipocresa robo',
#  'viene robo',
#  'robo prro',
#  'robo geniol',
#  'jajajajaja robo',
#  'jajajajaja robo',
#  'patrocinando robo',
#  'llama robo allanamiento',
#  'robo jadue',
#  'robo branding',
#  'robo descarado',
#  'robo mereca',
#  'si comparto robo',
#  'robo compermiso',
#  'andares robo',
#  'intensidad robo',
#  'asi comida robo',
#  'robo imagen',
#  'cobarda robo',
#  'pongo mscara robo',
#  'robo piola',
#  'alto robo fue',
#  'inseguridades robo',
#  'falsedaddd robo',
#  'amor robo',
#  'siga robo',
#  'susceptibilidad robo',
#  'saqueo robo',
#  'machismo robo amigaaaaaa',
#  'inters robo',
#  'vandalismo robo',
#  'envidia robo',
#  'robo historia',
#  'cara amigo robo',
#  'inters robo',
#  'grrrrrr basta robo',
#  'robo jajajaja',
#  'corto vaya robo',
#  'ganas robo',
#  'robo sensibilidad amiga',
#  'confianza robo',
#  'intensidad robo',
#  'robo hilo',
#  'ajajajaajajajajaj robo',
#  'originalidadno robo',
#  'jajajaja robo',
#  'primer robo noche',
#  'menudo robo chaval',
#  'robo partidos',
#  'que robo imagenes',
#  'si robo tweets romn',
#  'hipocresa robo',
#  'pesimismo robo',
#  'unas divas robo',
#  'robo memes',
#  'robo aficionados valla',
#  'robo grande visto',
#  'robo robas',
#  'amor robo',
#  'robo inexplicable',
#  'robo rizos',
#  'robo gero',
#  'ignorada robo',
#  'robo demasiado tipo',
#  'mmmm negri robo',
#  'ansiedad robo',
#  'personalidad robo',
#  'robo chiste',
#  'dlares eso tremendo robo',
#  'robo delfino ayer',
#  'robo devuelvo',
#  'robo meme',
#  'perro robo mas',
#  'contractura robo',
#  'ataco robo',
#  'robo historia',
#  'permitame robo',
#  'robo presidenciales',
#  'elizabeth robo',
#  'intensidad robo',
#  'actitud robo',
#  'compaerismo robo',
#  'dignidad robo',
#  'autoestima robo',
#  'jaaaa cuanto robo',
#  'desinters robo',
#  'robo gente',
#  'cualquier cosa incluye robo',
#  'bajn robo',
#  'robo siendo descomunal',
#  'pues robo ms',
#  'inmadurez robo',
#  'tremendo robo valladolid',
#  'robo despoblado valladolid',
#  'loco un robo',
#  'robo guante blanco',
#  'primer robo partido jojojo',
#  'fkdkdkekxkdkkssk ai robo',
#  'pronto empezamos robo',
#  'robo claramente',
#  'obvio robo ',
#  'brillante robo',
#  'por robo tuits',
#  'intensidad robo',
#  'robo amrica',
#  'robo naco',
#  'robo maldito',
#  'robo ol',
#  'jajaja robo',
#  'robo moto',
#  'superacin robo',
#  'robo levante',
#  'madre robo',
#  'intensidad robo',
#  'robo vez',
#  'robo descarado londres jaja',
#  'alto robo hijos puta',
#  'medio robo united',
#  'emociona robo united',
#  'riqusimo robo arsenal',
#  'robo arsenal mamita',
#  'resfro robo',
#  'acidez robo',
#  'confianza robo',
#  'conoces robo flip',
#  'intensidad robo',
#  'trauma robo',
#  'robo mamita',
#  'tremendo robo falton patricl roberts',
#  'incluye sidral robo',
#  'robo chocolatinas oxxo',
#  'pura mierdagrupo robo',
#  'misoginia robo',
#  'jajaja robo',
#  'justifica robo publico',
#  'robo imagen',
#  'mala suerte robo',
#  'contractura robo martaaa',
#  'insegurudad robo amigo',
#  'sta gripe robo amigo',
#  'armoso robo andy',
#  'extraar robo',
#  'suerte robo solange',
#  'robo qlo',
#  'robo meme',
#  'inseguridad robo amiga',
#  'robo amigo',
#  'rata robo millones',
#  'robo marte mercurio',
#  'robo uno',
#  'robo foto jaja',
#  'canelita robo bolsa monedas',
#  'toxicidad robo hermano',
#  'robo tambin',
#  'jajajajaa tocs robo',
#  'robo permisito',
#  'lesbianismo robo jajajajajaja',
#  'robo siglo',
#  'robo vengo baratico',
#  'no robo consumo adentro',
#  'amiga aburriendo robo',
#  'chiquito robo',
#  'hipocresia robo',
#  'callate robo',
#  'playback robo jajajajaj',
#  'alguien robo pagina',
#  'douuu robo primero',
#  'doble moral robo',
#  'tibieza robo amigo',
#  'concepto robo',
#  'jajajajaja robo',
#  'robo identidades ahora mira',
#  'contradiccin robo mabeeeel',
#  'robo foto',
#  'despus robo pkdora',
#  'suerte robo jajajaja',
#  'jajajaja originalidad robo',
#  'autuestima robo amiga',
#  'infop gran robo cachireco',
#  'doble moral robo',
#  'sueo beso robo',
#  'mala suerte robo',
#  'jajajajaja gato robo atencin',
#  'robo comonuna catedral',
#  'caradures robo',
#  'intensidad robo shabri',
#  'puto robo',
#  'vil robo',
#  'mejor me robo yo atte bronci',
#  'stalkeada robo mono',
#  'pongo mscara robo',
#  'parte robo',
#  'quin robo inocencia',
#  'fua esquivada robo',
#  'robo mscara gracias',
#  'sta ansiedad robo',
#  'contradicciones robo',
#  'micro robo seoras',
#  'si robo parejo',
#  'robo suerte',
#  'intensidad robo',
#  'reflexin robo amigaaaa',
#  'mas robo datos',
#  'entend justificas impunidad robo',
#  'intensidad robo magui',
#  'boluudaaa inseguridades robo',
#  'mmm idiotez robo',
#  'densidad robo amiga',
#  'organizacin robo',
#  'oye buba espuma robo idea',
#  'gramtica robo amiga',
#  'melancola robo',
#  'nervios robo',
#  'cara robo',
#  'celos robo amego',
#  'intensidad manejo robo',
#  'embole robo eh',
#  'tiren piropos lindos as robo',
#  'contractura robo',
#  'jajsjajaau encanto robo',
#  'resentimiento robo pibito',
#  'maldad robo',
#  'suerte robo hmno',
#  'robo ceja',
#  'tan diablo robo',
#  'bue redaccin robo',
#  'blindaje robo amigue',
#  'robo ya',
#  'marketing robo',
#  'buenna bipolaridad robo',
#  'suerte robo',
#  'crisis robo',
#  'resentimiendo kpo robo',
#  'trabajo robo',
#  'sinceridad robo',
#  'estereotipos robo amiga',
#  'federico robo corazn',
#  'robo derechistas sinverguenzas',
#  'hipocresa robo amigue',
#  'calidad imagen robo',
#  'robo meme gracias',
#  'robo gobierno',
#  'vida robo',
#  'robo primer gol',
#  'bue visto robo',
#  'redaccinno robo',
#  'alguien robo pole',
#  'prdida imbcil robo',
#  'suerte robo',
#  'loca robo corazon',
#  'robo meme permiso',
#  'manokkkkkkkkkjjkjkjkkkkkk robo buceta chorandokkjkkkjkk',
#  'nervios robo',
#  'adivinen robo',
#  'traumatismo robo ',
#  'robo joh',
#  'robo nombre',
#  'inmadurez robo hermano',
#  'alguien robo datos feis',
#  'desprecio robo jams',
#  'robo solo as ganan',
#  'resentimiento robo hno',
#  'inters robo amiga',
#  'robo siglo',
#  'jajajaja buitreadas robo',
#  'bue prioridades robo',
#  'robo pedo',
#  'jajaj robo no',
#  'cdigos robo ',
#  'fracaso robo',
#  'humor negro robo',
#  'entonces drogo robo mato pias',
#  'mae loca robo',
#  'mmm mentalidad robo',
#  'completo robo lacras deporte',
#  'sigue siendo robo ash',
#  'retrica robo',
#  'toxicidad robo amiga',
#  'robo banco seguro',
#  'mala onda robo',
#  'paciencia robo',
#  'saqueo robo',
#  'robo finquita desgraciado',
#  'si verdad robo',
#  'levante robo',
#  'robo platense van',
#  'villereada robo man',
#  'en dos dias robo',
#  'ignorancia robo amiga',
#  'petrleo cuba robo',
#  'robo sigue',
#  'robo exagerado',
#  'lgica robo amiga',
#  'desinteres robo',
#  'abstinencia robo amigo',
#  'autoestima manejo robo',
#  'puesto robo jjajaja',
#  'encanto robo',
#  'intensidad robo julieta',
#  'ansiedad robo',
#  'robo asolapado devuelvan robado',
#  'robo todas luces',
#  'robo pal face',
#  'm impuesto robo',
#  'masculinidad frgil robo',
#  'maldaaad robo jaja',
#  'justificar robo',
#  'todas luces robo base',
#  'bonita foto robo',
#  'emputado uro robo sala',
#  'vergenza ajena robo',
#  'gust robo',
#  'doble moral robo',
#  'calidad robo',
#  'enserio robo eso',
#  'llama robo',
#  'ansiedad robo',
#  'robo meme',
#  'robo siglo',
#  'robo adios',
#  'permiso robo',
#  'omo robo',
#  'comodidad robo pelotuda',
#  'robo comentariojaja',
#  'humedad robo',
#  'redaccion robo',
#  'costando robo',
#  'caos total vandalismo robo',
#  'lucas peaje robo',
#  'superacin robo',
#  'creo robo',
#  'rioboo robo vez ms',
#  'inseguridad robo amiga',
#  'meme robo jajajaja',
#  'intensidad robo hna',
#  'pewe ser robo secreto',
#  'espaol robo amigoooooo',
#  'jaja robo',
#  'culo sucio robo',
#  'robar tweets mejor robo besos',
#  'robar tweets mejor robo besos',
#  'madurez robo amigo',
#  'robo loot',
#  'mmmm inseguridad robo',
#  'traduccin robo',
#  'problemas robo',
#  'ansiedad robo ',
#  'memes robo',
#  'efectos robo amigo',
#  'suerte robo',
#  'encanto robo',
#  'robo barn',
#  'furious robo barn semana',
#  'robo pido prestado',
#  'hombre robo corazn',
#  'celos robo',
#  'humedad robo amigo',
#  'autoestima robo bro',
#  'intensidad robo jajajaj',
#  'robo sabes chau',
#  'egosmo robo amigo',
#  'desesperacin robo amigo',
#  'robo meme ahre',
#  'falsedad robo amiga',
#  'penal robo abal',
#  'robo frases siguen prefiriendo',
#  'xddd robo',
#  'gordo valor robo',
#  'reputacin robo amigo',
#  'robo gigante',
#  'vaya robo pobre lvaro',
#  'entiendo robo lvaro',
#  'robo nadie okei',
#  'orgullo robo',
#  'toxicidad robo',
#  'felicidad robo',
#  'originalidad robo',
#  'encant robo',
#  'racing robo punto capo',
#  'ida robo brutal',
#  'no sido robo mano armada',
#  'sa bola amigo robo',
#  'amor robo',
#  'robo meme loto',
#  'viene robo',
#  'robo sido asqueroso',
#  'ambivalencia robo agustn',
#  'robo mucha pia',
#  'honestidad robo',
#  'mala suerte robo',
#  'jajajajaja retraso robo',
#  'mal humor robo',
#  'robo compaero',
#  'menudo robo rosaleda seores',
#  'avala robo hormiga',
#  'zonambulismo robo',
#  'suerte si robo',
#  'robo pinturas',
#  'perdn robo descarado',
#  'seor simple robo codicia',
#  'pens nunca vivir semejante robo',
#  'si robo',
#  'audacia robo',
#  'rateroses robo asolapado',
#  'variar justificando robo',
#  'sueo beso robo',
#  'inters robo',
#  'robo combustible',
#  'robo mujer',
#  'injusto completo robo',
#  'robo riverita',
#  'robaselos aunque seria robo',
#  'desinters robo bro',
#  'baja autoestima robo',
#  'robo carnaval',
#  'ah entonces robo pues',
#  'pillajerobo',
#  'fanatismo oculto robo',
#  'asociemos robo',
#  'amiga robo',
#  'planeado robo banco',
#  'robo legal tipo pirmide',
#  'mayor robo dortmund',
#  'vagancia robo',
#  'suerte robo',
#  'robo besito',
#  'robo plata pearol',
#  'ganas robo',
#  'messi laburoel robo',
#  'espero sino vaya robo',
#  'mala leche robo',
#  'suerte robo eh',
#  'si robo beso',
#  'robo korason ahre',
#  'inseguridad robo amiga',
#  'inestabilidad emocional robo',
#  'humildad robo',
#  'aunque robo users',
#  'truenos robo mabeeel',
#  'se inters robo',
#  'tuitazo deja robo',
#  'robo museo carondelet',
#  'famoso robo hormiga',
#  'robo sigue seguir siempre',
#  'robo puto madriz baboso',
#  'opinas robo',
#  'resaca robo amiga',
#  'robo descarado zorrilla apa pucela',
#  'dnde robo',
#  'toxicidad robo',
#  'menudo robo dais pena',
#  'penal valladolid mamita robo',
#  'resaca robo amiga',
#  'robo meme gracias',
#  'desconfianza robo amiguita',
#  'organizacin robo amigo',
#  'vamos empieza robo valladolid',
#  'ay madre robo',
#  'robe robo',
#  'venezuela robo rayo zeus',
#  'llor sensibilidad robo',
#  'robo moto',
#  'morbo robo asco',
#  'chamuyo robo amigo',
#  'boludes mental robo',
#  'robo asesinatos impunidad gollerias etc',
#  'indirectas robo activ',
#  'dignidad robo',
#  'estafa robo nacional',
#  'semana mas puto robo',
#  'cuernos robo amixxx',
#  'inters robo hno',
#  'robo mano armada',
#  'relaxion toxica robo',
#  'impuestos robo',
#  'lgica robo',
#  'voy robo',
#  'hembrismo robo amiga',
#  'resaca robo',
#  'llor sensibilidad robo',
#  'robo camisa ',
#  'autoestima robo jajajajajaja',
#  'giane robo videos',
#  'robo moto',
#  'kirchenrismo robo no',
#  'funk robo corazn jajaja',
#  'nanana dignidad robo',
#  'dios densidad robo',
#  'inestabilidad emocional robo',
#  'deseo inconsciente robo',
#  'robo funda movil',
#  'doble moral robo amigue',
#  'robo bio',
#  'jajajajaja permiso robo tuit',
#  'ganas hablar robo',
#  'resentimiento robo jajajajajajaj',
#  'river robo boca madrid',
#  'despus robo seguro social',
#  'asalto robo extorsin secuestro desaparicin',
#  'maldad robo jajajajjaja',
#  'mmm empata robo bro',
#  'jajajajajajaja agresividad robo hermano',
#  'respeto robo',
#  'mmmmm justificacin robo amigo',
#  'robo ganado',
#  'nop asi robo ahre',
#  'si gana rodri robo',
#  'robo lindos',
#  'encant jajajaja robo mary',
#  'robo pld',
#  'maana robo jajajajja',
#  'idea solo robo',
#  'desinters manejaaaa robo',
#  'nunca voy pordonar robo',
#  'incomodidad sentiste robo',
#  'robo gol',
#  'mmmm dependencia robo amiga',
#  'materia pedorra robo',
#  'paz tranquilidad nos robo correa',
#  'puta madre planeando robo',
#  'lesbianismo robo jajajajajaja',
#  'preocupacin robo',
#  'llama robo violencia',
#  'solo robo tuits tienen twitter for iphone',
#  'robo cario lolas',
#  'cuidado robo eeeh',
#  'trnsito robo amigo',
#  'nervios pre rendida robo',
#  'cansancio fsico robo rubn',
#  'jajajaja robo',
#  'robo mas dejar',
#  'nivel falsedad robo',
#  'si robo poder ',
#  'cerebro robo ',
#  'facha amigo robo',
#  'setlist robo amigo',
#  'buen robo imagen',
#  'capacidad flashearla robo',
#  'disyuntiva interna robo valesca',
#  'parece puto robo',
#  'ignorancia robo',
#  'ganas laburar robo',
#  'negacionismo negar robo cristina',
#  'quisiste decir robo historico no',
#  'amistad robo',
#  'suerte robo amigo',
#  'nivel demencia robo',
#  'entiendo cristina robo pruebas',
#  'redaccin robo amea',
#  'resaca viernes robo',
#  'mal humor robo hermana',
#  'robo jode',
#  'mmm inestabilidad emocional robo',
#  'necesidad atencin robo',
#  'robo verdad',
#  'esperanzas robo',
#  'ortografia robo',
#  'bruto robo hijos puta jajaj',
#  'colorada robo toda atencin',
#  'ministro ministro robo',
#  'jajajajajajaja imagen robo',
#  'ignorada robo permuto',
#  'deberan desaforarlos robo seores',
#  'robo coca esc',
#  'robo pelfecto nueva partner crime',
#  'venga robo nomas',
#  'defensas bajas robo amigo',
#  'argumento robo',
#  'morocho robo penal',
#  'saqueo mierda robo',
#  'ay xdio eta resaca robo',
#  'maana hoy robo amiga',
#  'ahora robo llama distraccin',
#  'tooooooodo voy perder distraccin robo',
#  'polica robo',
#  'sopermi robo meme',
#  'puedo superar robo lentes',
#  'mia robo ysi',
#  'pueblo llaman robo',
#  'robo ta falta juanchi',
#  'jajajajajajaa bipolaridad robo',
#  'rbitro robo cara descubierta',
#  'dos penales cobraron robo viejo',
#  'conmebol gallina robo penales',
#  'dignidad robo palo',
#  'robo var cmplice',
#  'cha madre fkn robo casa',
#  'instagram ahora robo memes',
#  'robo toda macri',
#  'dudas robo amiga',
#  'cuentas robo amiga',
#  'chamuyos pedorros flacono robo',
#  'no trabajo seguramente robo',
#  'dependencia bro robo',
#  'descuides robo',
#  'vejez si robo',
#  'bajones emocionales robo amigo',
#  's robo jajaj',
#  'robo frase',
#  ...]

# %%
len(datos_limp)
# Out:
# 10651

# %% [markdown]
# ### Text frecuency - Inverse Document Frecuency

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import matplotlib.pyplot as plt

# %%
def tokenizer(text):
    words = nltk.word_tokenize(text)
    return words

# %%
texts = datos_limp
max_features = 1000

# %%
tfidf = TfidfVectorizer(tokenizer=tokenizer, stop_words=stops, max_features=max_features)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
sparse_tfidf_texts = tfidf.fit_transform(texts)

# %%
print(sparse_tfidf_texts.shape)
# Out:
# (10663, 1000)

# %%
train_idx = np.random.choice(sparse_tfidf_texts.shape[0], round(0.8*sparse_tfidf_texts.shape[0]), replace=False)
test_idx = np.array(list(set(range(sparse_tfidf_texts.shape[0]))-set(train_idx)))

# %% [markdown]
# ### Skip grams

# %%
import collections

# %%
batch_size = 50
num_sampled = int(batch_size/2)
embedding_size = 200
generations = 50000
vocabulary_size = 10000
print_loss_every = 500
window_size = 2
print_valid_every = 2000
#valid_words = ['robo', 'policia', 'modalidad', 'familia', 'ladron', 'atraco']
valid_words = ['policia', 'modalidad', 'atraco']
#valid_words_littte = ['policia', 'modalidad', 'atraco']

# %%
def build_dictionary(sentences, vocabulary_size):
    split_sentences = [s.split() for s in sentences]
    words = [x for sublist in split_sentences for x in sublist] #if len(x) < 3]
    count = [['RARE', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    word_dict = {}
    for word, word_count in count:
        word_dict[word] = len(word_dict)
    return word_dict

# %%
word_dict = build_dictionary(datos_limp, vocabulary_size)

# %%
word_dict
# Out:
# {'RARE': 0,
#  'robo': 1,
#  'si': 2,
#  'millones': 3,
#  'dos': 4,
#  'va': 5,
#  'aos': 6,
#  'reporte': 7,
#  'dlares': 8,
#  'mas': 9,
#  'combustible': 10,
#  'da': 11,
#  'daddy': 12,
#  'yankee': 13,
#  'amiga': 14,
#  'joyas': 15,
#  'polica': 16,
#  'impactante': 17,
#  'sufre': 18,
#  'ser': 19,
#  'ahora': 20,
#  'casa': 21,
#  'valuadas': 22,
#  'solo': 23,
#  'as': 24,
#  'dinero': 25,
#  'hoy': 26,
#  'amigo': 27,
#  'rob': 28,
#  'delito': 29,
#  'vehculo': 30,
#  'mil': 31,
#  'corrupcin': 32,
#  'ver': 33,
#  'hace': 34,
#  'no': 35,
#  'vehculos': 36,
#  'el': 37,
#  'mano': 38,
#  'gente': 39,
#  'de': 40,
#  'saqueo': 41,
#  'tan': 42,
#  'pas': 43,
#  'puede': 44,
#  'intento': 45,
#  'detienen': 46,
#  'mismo': 47,
#  'parte': 48,
#  'seguro': 49,
#  'falta': 50,
#  'gran': 51,
#  'hacer': 52,
#  'bien': 53,
#  'vez': 54,
#  'pueblo': 55,
#  'siempre': 56,
#  'despus': 57,
#  'descarado': 58,
#  'menos': 59,
#  'tras': 60,
#  'auto': 61,
#  'san': 62,
#  'detiene': 63,
#  'decir': 64,
#  'plata': 65,
#  'suerte': 66,
#  'gobierno': 67,
#  'video': 68,
#  'robos': 69,
#  'tres': 70,
#  'hombre': 71,
#  'la': 72,
#  'voy': 73,
#  'denuncia': 74,
#  'violencia': 75,
#  'armada': 76,
#  'hizo': 77,
#  'mal': 78,
#  'das': 79,
#  'celular': 80,
#  'intensidad': 81,
#  'alguien': 82,
#  'bueno': 83,
#  'presidente': 84,
#  'dice': 85,
#  'en': 86,
#  'nunca': 87,
#  'cuenta': 88,
#  'mayor': 89,
#  'personas': 90,
#  'ganas': 91,
#  'jajajaja': 92,
#  'detenidos': 93,
#  'cmo': 94,
#  'jajaja': 95,
#  'sujeto': 96,
#  'detenido': 97,
#  'vida': 98,
#  'mejor': 99,
#  'caso': 100,
#  'cada': 101,
#  'mxico': 102,
#  'sigue': 103,
#  'banda': 104,
#  'acusado': 105,
#  'foto': 106,
#  'mcgregor': 107,
#  'mujer': 108,
#  'toda': 109,
#  'cara': 110,
#  'igual': 111,
#  'ao': 112,
#  'dios': 113,
#  'quiero': 114,
#  'combate': 115,
#  'historia': 116,
#  'cuatro': 117,
#  'camin': 118,
#  'tener': 119,
#  'asalto': 120,
#  'favor': 121,
#  'prisin': 122,
#  'nadie': 123,
#  'ayer': 124,
#  'pesos': 125,
#  'primer': 126,
#  'conor': 127,
#  'ladrones': 128,
#  'cosas': 129,
#  'vaya': 130,
#  'puta': 131,
#  'corazn': 132,
#  'van': 133,
#  'ir': 134,
#  'venezuela': 135,
#  'es': 136,
#  'metro': 137,
#  'claro': 138,
#  'vos': 139,
#  'hicieron': 140,
#  'hombres': 141,
#  'paso': 142,
#  'policas': 143,
#  'partido': 144,
#  'gracias': 145,
#  'joven': 146,
#  'venezolanos': 147,
#  'seguridad': 148,
#  'aqu': 149,
#  'usted': 150,
#  'sido': 151,
#  'nacional': 152,
#  'etc': 153,
#  'roban': 154,
#  'asi': 155,
#  'grande': 156,
#  'madre': 157,
#  'todas': 158,
#  'debe': 159,
#  'hecho': 160,
#  'que': 161,
#  'creo': 162,
#  'combustibles': 163,
#  'llama': 164,
#  'tiempo': 165,
#  'verdad': 166,
#  'ustedes': 167,
#  'qu': 168,
#  'nuevo': 169,
#  'dijo': 170,
#  'final': 171,
#  'pasa': 172,
#  'penal': 173,
#  'casi': 174,
#  'ladrn': 175,
#  'proceso': 176,
#  'agua': 177,
#  'habitacin': 178,
#  'maana': 179,
#  'nivel': 180,
#  'informacin': 181,
#  'tipo': 182,
#  'persona': 183,
#  'se': 184,
#  'robar': 185,
#  'momento': 186,
#  'estatal': 187,
#  'delitos': 188,
#  'madrid': 189,
#  'hambre': 190,
#  'pagar': 191,
#  'hacen': 192,
#  'mierda': 193,
#  'estn': 194,
#  'acuerdo': 195,
#  'ataque': 196,
#  'pueden': 197,
#  'carabineros': 198,
#  'obesidad': 199,
#  'permitir': 200,
#  'nada': 201,
#  'luego': 202,
#  'plebiscito': 203,
#  'arrestado': 204,
#  'ms': 205,
#  'banco': 206,
#  'trabajo': 207,
#  'advisors': 208,
#  'moldeando': 209,
#  'fintech': 210,
#  'delincuente': 211,
#  'asegura': 212,
#  'fiscala': 213,
#  'calle': 214,
#  'pblico': 215,
#  'viene': 216,
#  'pues': 217,
#  'vctima': 218,
#  'luz': 219,
#  'puedo': 220,
#  'nico': 221,
#  'cuesta': 222,
#  'cosa': 223,
#  'quiere': 224,
#  'semana': 225,
#  'propiedad': 226,
#  'parece': 227,
#  'justicia': 228,
#  'cristina': 229,
#  'mientras': 230,
#  'jajajajaja': 231,
#  'todo': 232,
#  'puebla': 233,
#  'sujetos': 234,
#  'veo': 235,
#  'peor': 236,
#  'jaja': 237,
#  'twitter': 238,
#  'fraude': 239,
#  'hijo': 240,
#  'corrupto': 241,
#  'robaron': 242,
#  'medio': 243,
#  'deben': 244,
#  'ah': 245,
#  'general': 246,
#  'millonario': 247,
#  'relojes': 248,
#  'delincuentes': 249,
#  'mira': 250,
#  'presunto': 251,
#  'social': 252,
#  'juan': 253,
#  'hora': 254,
#  'transporte': 255,
#  'conductor': 256,
#  'hablar': 257,
#  'entonces': 258,
#  'ahre': 259,
#  'var': 260,
#  'fotos': 261,
#  'vas': 262,
#  'plan': 263,
#  'abuso': 264,
#  'centro': 265,
#  'familia': 266,
#  'mundo': 267,
#  'hidrocarburos': 268,
#  'vergenza': 269,
#  'eso': 270,
#  'debera': 271,
#  'empresa': 272,
#  'arrestan': 273,
#  'resultados': 274,
#  'pertenencias': 275,
#  'supuesto': 276,
#  'camioneta': 277,
#  'hermano': 278,
#  'datos': 279,
#  'buenos': 280,
#  'asesinato': 281,
#  'pais': 282,
#  'sistema': 283,
#  'evitar': 284,
#  'mediante': 285,
#  'gol': 286,
#  'detuvieron': 287,
#  'impuestos': 288,
#  'slo': 289,
#  'manera': 290,
#  'seor': 291,
#  'moto': 292,
#  'mala': 293,
#  'haciendo': 294,
#  'miami': 295,
#  'noticias': 296,
#  'los': 297,
#  'fiscal': 298,
#  'sabe': 299,
#  'criminal': 300,
#  'identidad': 301,
#  'carlos': 302,
#  'vamos': 303,
#  'inseguridad': 304,
#  'ansiedad': 305,
#  'por': 306,
#  'dar': 307,
#  'vivienda': 308,
#  'violento': 309,
#  'grave': 310,
#  'costosos': 311,
#  'digo': 312,
#  'tal': 313,
#  'preso': 314,
#  'nacin': 315,
#  'meme': 316,
#  'hijos': 317,
#  'estrategia': 318,
#  'dicen': 319,
#  'acabo': 320,
#  'sabotaje': 321,
#  'color': 322,
#  'sos': 323,
#  'preventiva': 324,
#  'gas': 325,
#  'nmero': 326,
#  'tambien': 327,
#  'rata': 328,
#  'beso': 329,
#  'yo': 330,
#  'sabes': 331,
#  'deja': 332,
#  'an': 333,
#  'menor': 334,
#  'devuelva': 335,
#  'ro': 336,
#  'recupera': 337,
#  'votar': 338,
#  'colombia': 339,
#  'gasolina': 340,
#  'cuanto': 341,
#  'del': 342,
#  'cambio': 343,
#  'iba': 344,
#  'roba': 345,
#  'sueo': 346,
#  'vandalismo': 347,
#  'siglo': 348,
#  'veces': 349,
#  'ley': 350,
#  'via': 351,
#  'mentira': 352,
#  'atencin': 353,
#  'muerte': 354,
#  'tampoco': 355,
#  'encima': 356,
#  'hurto': 357,
#  'sino': 358,
#  'autos': 359,
#  'ivss': 360,
#  'primero': 361,
#  'fin': 362,
#  'necesidad': 363,
#  'macri': 364,
#  'llevan': 365,
#  'ac': 366,
#  'dio': 367,
#  'pemex': 368,
#  'luchador': 369,
#  'ayudar': 370,
#  'apresa': 371,
#  'tu': 372,
#  'nueva': 373,
#  'seguir': 374,
#  'congreso': 375,
#  'un': 376,
#  'gana': 377,
#  'espero': 378,
#  'segundo': 379,
#  'cabeza': 380,
#  'arma': 381,
#  'pasado': 382,
#  'mantenimiento': 383,
#  'dao': 384,
#  'haber': 385,
#  'tienda': 386,
#  'denunciar': 387,
#  'le': 388,
#  'frustra': 389,
#  'incitando': 390,
#  'elementos': 391,
#  'vigente': 392,
#  'mdico': 393,
#  'tiros': 394,
#  'organizacin': 395,
#  'estado': 396,
#  'viejo': 397,
#  'idea': 398,
#  'diario': 399,
#  'me': 400,
#  'cualquier': 401,
#  'doble': 402,
#  'quieren': 403,
#  'cierto': 404,
#  'dia': 405,
#  'armas': 406,
#  'investigacin': 407,
#  'descubre': 408,
#  'chavez': 409,
#  'lo': 410,
#  'recursos': 411,
#  'central': 412,
#  'puto': 413,
#  'sensibilidad': 414,
#  'noche': 415,
#  'nombre': 416,
#  'secuestro': 417,
#  's': 418,
#  'estan': 419,
#  'justo': 420,
#  'mam': 421,
#  'despues': 422,
#  'llevo': 423,
#  'habla': 424,
#  'culpa': 425,
#  'mensajes': 426,
#  'alerta': 427,
#  'horas': 428,
#  'original': 429,
#  'cubre': 430,
#  'civil': 431,
#  'pena': 432,
#  'basta': 433,
#  'forma': 434,
#  'misma': 435,
#  'acaba': 436,
#  'hola': 437,
#  'probable': 438,
#  'tremendo': 439,
#  'permiso': 440,
#  'amor': 441,
#  'dolor': 442,
#  'pruebas': 443,
#  'hermana': 444,
#  'nios': 445,
#  'hago': 446,
#  'conmigo': 447,
#  'meses': 448,
#  'comer': 449,
#  'fuerza': 450,
#  'detuvo': 451,
#  'serie': 452,
#  'privada': 453,
#  'homicidio': 454,
#  'guardia': 455,
#  'energa': 456,
#  'carro': 457,
#  'escuela': 458,
#  'odio': 459,
#  'autor': 460,
#  'te': 461,
#  'sale': 462,
#  'jajajajajaja': 463,
#  'ay': 464,
#  'ganado': 465,
#  'crcel': 466,
#  'precio': 467,
#  'todava': 468,
#  'adems': 469,
#  'delincuencia': 470,
#  'elctrico': 471,
#  'comercio': 472,
#  'tripulacin': 473,
#  'tractocamiones': 474,
#  'autoridades': 475,
#  'colonia': 476,
#  'diciendo': 477,
#  'rt': 478,
#  'aunque': 479,
#  'alto': 480,
#  'cmplice': 481,
#  'lugar': 482,
#  'calificado': 483,
#  'equipo': 484,
#  'emocional': 485,
#  'poder': 486,
#  'salud': 487,
#  'novio': 488,
#  'sola': 489,
#  'minutos': 490,
#  'sufri': 491,
#  'llorar': 492,
#  'ciudad': 493,
#  'tema': 494,
#  'responsable': 495,
#  'miles': 496,
#  'agresin': 497,
#  'agravado': 498,
#  'viajaba': 499,
#  'subterrneo': 500,
#  'par': 501,
#  'posible': 502,
#  'autopartes': 503,
#  'siento': 504,
#  'dolares': 505,
#  'como': 506,
#  'levante': 507,
#  'buen': 508,
#  'instagram': 509,
#  'siendo': 510,
#  'estafa': 511,
#  'paz': 512,
#  'menores': 513,
#  'pap': 514,
#  'anda': 515,
#  'lpez': 516,
#  'robando': 517,
#  'saben': 518,
#  'segn': 519,
#  'santa': 520,
#  'servicio': 521,
#  'frente': 522,
#  'violacin': 523,
#  'tenia': 524,
#  'intimidacin': 525,
#  'algn': 526,
#  'favorito': 527,
#  'obrador': 528,
#  'motocicleta': 529,
#  'lado': 530,
#  'protegerte': 531,
#  'libre': 532,
#  'caraduras': 533,
#  'frustrado': 534,
#  'justifica': 535,
#  'uso': 536,
#  'total': 537,
#  'impunidad': 538,
#  'marzo': 539,
#  'domingo': 540,
#  'valladolid': 541,
#  'dnde': 542,
#  'inters': 543,
#  'vivir': 544,
#  'pobre': 545,
#  'boca': 546,
#  'nio': 547,
#  'documentos': 548,
#  'pasar': 549,
#  'escobar': 550,
#  'pbi': 551,
#  'mes': 552,
#  'dije': 553,
#  'queda': 554,
#  'padre': 555,
#  'nota': 556,
#  'cinco': 557,
#  'presidencia': 558,
#  'defendi': 559,
#  'sacrlego': 560,
#  'boxeador': 561,
#  'euros': 562,
#  'coberturas': 563,
#  'eliges': 564,
#  'alojan': 565,
#  'elctrica': 566,
#  'ellos': 567,
#  'dentro': 568,
#  'barrio': 569,
#  'combatir': 570,
#  'todos': 571,
#  'daos': 572,
#  'unas': 573,
#  'memes': 574,
#  'robado': 575,
#  'facebook': 576,
#  'bastante': 577,
#  'libertad': 578,
#  'realidad': 579,
#  'grupo': 580,
#  'ojal': 581,
#  'denuncian': 582,
#  'muerto': 583,
#  'cae': 584,
#  'investiga': 585,
#  'ssp': 586,
#  'ninguna': 587,
#  'amlo': 588,
#  'bicicleta': 589,
#  'beach': 590,
#  'dan': 591,
#  'aseguran': 592,
#  'autoridad': 593,
#  'co': 594,
#  'responsables': 595,
#  'mexicanos': 596,
#  'real': 597,
#  'serio': 598,
#  'dedicada': 599,
#  'redujo': 600,
#  'rotondaro': 601,
#  'hacia': 602,
#  'sra': 603,
#  'llamar': 604,
#  'lpm': 605,
#  'fav': 606,
#  'imagen': 607,
#  'dignidad': 608,
#  'quin': 609,
#  'ya': 610,
#  'pedo': 611,
#  'cuba': 612,
#  'punto': 613,
#  'mucha': 614,
#  'llevaron': 615,
#  'hablando': 616,
#  'capital': 617,
#  'sexual': 618,
#  'resultado': 619,
#  'prescribe': 620,
#  'manolo': 621,
#  'sabemos': 622,
#  'bajo': 623,
#  'muri': 624,
#  'anoche': 625,
#  'municipal': 626,
#  'venezolano': 627,
#  'seora': 628,
#  'esto': 629,
#  'acusados': 630,
#  'parque': 631,
#  'presuntos': 632,
#  'hice': 633,
#  'hostias': 634,
#  'termine': 635,
#  'sol': 636,
#  'buenas': 637,
#  'miedo': 638,
#  'comida': 639,
#  'qued': 640,
#  'juez': 641,
#  'alta': 642,
#  'chvez': 643,
#  'negocio': 644,
#  'menudo': 645,
#  'gato': 646,
#  'tweet': 647,
#  'loco': 648,
#  'crisis': 649,
#  'puesto': 650,
#  'extorsin': 651,
#  'rbitro': 652,
#  'ganar': 653,
#  'primera': 654,
#  'papa': 655,
#  'masivo': 656,
#  'argentinos': 657,
#  'pobres': 658,
#  'dejo': 659,
#  'pago': 660,
#  'ningn': 661,
#  'buena': 662,
#  'mochila': 663,
#  'trabajar': 664,
#  'corruptos': 665,
#  'juego': 666,
#  'rato': 667,
#  'tarde': 668,
#  'haga': 669,
#  'vino': 670,
#  'recuperan': 671,
#  'junto': 672,
#  'catrillanca': 673,
#  'argentina': 674,
#  'ces': 675,
#  'oms': 676,
#  'homicidios': 677,
#  'consagradas': 678,
#  'esperan': 679,
#  'balazos': 680,
#  'producto': 681,
#  'cloro': 682,
#  'causa': 683,
#  'repblica': 684,
#  'habl': 685,
#  'acciones': 686,
#  'gan': 687,
#  'delictiva': 688,
#  'triste': 689,
#  'reportan': 690,
#  'funcionarios': 691,
#  'informa': 692,
#  'motochorro': 693,
#  'legal': 694,
#  'media': 695,
#  'gusta': 696,
#  'puedes': 697,
#  'fue': 698,
#  'asesinatos': 699,
#  'deberan': 700,
#  'penales': 701,
#  'lindo': 702,
#  'orto': 703,
#  'pudo': 704,
#  'pinche': 705,
#  'ladron': 706,
#  'aqui': 707,
#  'volver': 708,
#  'importa': 709,
#  'gastos': 710,
#  'chile': 711,
#  'europa': 712,
#  'llega': 713,
#  'falsos': 714,
#  'lunes': 715,
#  'hija': 716,
#  'santos': 717,
#  'air': 718,
#  'juicio': 719,
#  'detencin': 720,
#  'zona': 721,
#  'existe': 722,
#  'municipio': 723,
#  'pblica': 724,
#  'ruta': 725,
#  'unidades': 726,
#  'sagrario': 727,
#  'copones': 728,
#  'titular': 729,
#  'ma': 730,
#  'siete': 731,
#  'estatales': 732,
#  'edo': 733,
#  'maduro': 734,
#  'estudios': 735,
#  'para': 736,
#  'asco': 737,
#  'jajajajajajaja': 738,
#  'all': 739,
#  'espaa': 740,
#  'puro': 741,
#  'hay': 742,
#  'denunci': 743,
#  'justificar': 744,
#  'club': 745,
#  'condena': 746,
#  'dems': 747,
#  'unidad': 748,
#  'perro': 749,
#  'increble': 750,
#  'petrleo': 751,
#  'bro': 752,
#  'victima': 753,
#  'siquiera': 754,
#  'vivo': 755,
#  'che': 756,
#  'fondos': 757,
#  'tapar': 758,
#  'hdp': 759,
#  'mujeres': 760,
#  'fuego': 761,
#  'ayuda': 762,
#  'lleg': 763,
#  'cuantos': 764,
#  'departamento': 765,
#  'interior': 766,
#  'patrimonio': 767,
#  'extrao': 768,
#  'ven': 769,
#  'cigarrillos': 770,
#  'ciudadanos': 771,
#  'orden': 772,
#  'pedro': 773,
#  'vinculacin': 774,
#  'captan': 775,
#  'logr': 776,
#  'polticos': 777,
#  'acto': 778,
#  'eeuu': 779,
#  'mercanca': 780,
#  'cometido': 781,
#  'entran': 782,
#  'cel': 783,
#  'chavismo': 784,
#  'esperar': 785,
#  'vuelve': 786,
#  'crescenti': 787,
#  'pea': 788,
#  'bancos': 789,
#  'trata': 790,
#  'diarios': 791,
#  'denuncias': 792,
#  'maldito': 793,
#  'impuesto': 794,
#  'visto': 795,
#  'novia': 796,
#  'perdn': 797,
#  'pongo': 798,
#  'dias': 799,
#  'hablo': 800,
#  'control': 801,
#  'escandaloso': 802,
#  'campo': 803,
#  'cuello': 804,
#  'redes': 805,
#  'chelsea': 806,
#  'problema': 807,
#  'amo': 808,
#  'red': 809,
#  'feliz': 810,
#  'vale': 811,
#  'cfk': 812,
#  'puso': 813,
#  'malo': 814,
#  'chica': 815,
#  'recuerdo': 816,
#  'varios': 817,
#  'dormir': 818,
#  'leer': 819,
#  'empresas': 820,
#  'profesoras': 821,
#  'hablan': 822,
#  'doy': 823,
#  'cundo': 824,
#  'cajero': 825,
#  'normal': 826,
#  'tesoro': 827,
#  'urgente': 828,
#  'aparte': 829,
#  'elecciones': 830,
#  'comprar': 831,
#  'ejemplo': 832,
#  'den': 833,
#  'inversin': 834,
#  'lnea': 835,
#  'carne': 836,
#  'lucha': 837,
#  'fujimorista': 838,
#  'vinculado': 839,
#  'afirma': 840,
#  'dej': 841,
#  'apoyo': 842,
#  'sector': 843,
#  'apagn': 844,
#  'william': 845,
#  'mordidas': 846,
#  'puntos': 847,
#  'quedar': 848,
#  'destruccin': 849,
#  'izquierda': 850,
#  'po': 851,
#  'voto': 852,
#  'llegar': 853,
#  'internet': 854,
#  'tercer': 855,
#  'una': 856,
#  'dicho': 857,
#  'con': 858,
#  'pdi': 859,
#  'sacar': 860,
#  'jams': 861,
#  'autoestima': 862,
#  'sea': 863,
#  'moral': 864,
#  'humor': 865,
#  'simple': 866,
#  'tambin': 867,
#  'chiquito': 868,
#  'mmm': 869,
#  'manejo': 870,
#  'problemas': 871,
#  'dejar': 872,
#  'verga': 873,
#  'poca': 874,
#  'coo': 875,
#  'estabilidad': 876,
#  'compra': 877,
#  'llorando': 878,
#  'incompetencia': 879,
#  'sociales': 880,
#  'hablas': 881,
#  'mio': 882,
#  'empezar': 883,
#  'poner': 884,
#  'campaa': 885,
#  'verdadero': 886,
#  'las': 887,
#  'pelo': 888,
#  'esperando': 889,
#  'algo': 890,
#  'rojo': 891,
#  'punta': 892,
#  'hidrocarburo': 893,
#  'afp': 894,
#  'creer': 895,
#  'huachicol': 896,
#  'pide': 897,
#  'investigan': 898,
#  'premian': 899,
#  'barriles': 900,
#  'basura': 901,
#  'fge': 902,
#  'sali': 903,
#  'amigos': 904,
#  'viendo': 905,
#  'local': 906,
#  'corrupcion': 907,
#  'oro': 908,
#  'alguna': 909,
#  'reales': 910,
#  'jugador': 911,
#  'afecta': 912,
#  'seis': 913,
#  'comisin': 914,
#  'saqueos': 915,
#  'vea': 916,
#  'automvil': 917,
#  'kari': 918,
#  'innegable': 919,
#  'evidencian': 920,
#  'venezolana': 921,
#  'buscar': 922,
#  'ciudadano': 923,
#  'equipos': 924,
#  'resisti': 925,
#  'aumento': 926,
#  'pesar': 927,
#  'tierras': 928,
#  'representacion': 929,
#  'guerra': 930,
#  'al': 931,
#  'saab': 932,
#  'totalmente': 933,
#  'descaro': 934,
#  'error': 935,
#  'periodista': 936,
#  'derecho': 937,
#  'razn': 938,
#  'confianza': 939,
#  'frustrar': 940,
#  'devolver': 941,
#  'piensa': 942,
#  'm': 943,
#  'asqueroso': 944,
#  'obvio': 945,
#  'bipolaridad': 946,
#  'onda': 947,
#  'siguen': 948,
#  'seores': 949,
#  'baja': 950,
#  'inestabilidad': 951,
#  'tuit': 952,
#  'river': 953,
#  'ministro': 954,
#  'reportar': 955,
#  'solamente': 956,
#  'excusa': 957,
#  'colectivo': 958,
#  'pri': 959,
#  'sigo': 960,
#  'y': 961,
#  'pasada': 962,
#  'ropa': 963,
#  'mundial': 964,
#  'copa': 965,
#  'bebs': 966,
#  'hagan': 967,
#  'vecino': 968,
#  'ineficiencia': 969,
#  'terminar': 970,
#  'viva': 971,
#  'padres': 972,
#  'haces': 973,
#  'ahorro': 974,
#  'vieja': 975,
#  'ello': 976,
#  'carta': 977,
#  'comn': 978,
#  'pero': 979,
#  'psg': 980,
#  'pregunta': 981,
#  'barcelona': 982,
#  'vctimas': 983,
#  'celulares': 984,
#  'goles': 985,
#  'ojala': 986,
#  'cantidad': 987,
#  'so': 988,
#  'pensando': 989,
#  'ti': 990,
#  'culpable': 991,
#  'diga': 992,
#  'habia': 993,
#  'mvil': 994,
#  'entro': 995,
#  'chorra': 996,
#  'noticia': 997,
#  'vdeo': 998,
#  'us': 999,
#  ...}

# %%
def text_to_numbers(sentences, word_dict):
    data = []
    for sentence in sentences:
        sentence_data = []
        for word in sentence:
            if word in word_dict:
                word_ix = word_dict[word] #posición/ID de la palabra en el word dict
            else:
                word_ix = 0 ##posición/ID de la palabra RARE
            sentence_data.append(word_ix)
        data.append(sentence_data)
    return data

# %%
word_dict_rev = dict(zip(word_dict.values(), word_dict.keys()))
word_dict_rev
# Out:
# {0: 'RARE',
#  1: 'robo',
#  2: 'si',
#  3: 'millones',
#  4: 'dos',
#  5: 'va',
#  6: 'aos',
#  7: 'reporte',
#  8: 'dlares',
#  9: 'mas',
#  10: 'combustible',
#  11: 'da',
#  12: 'daddy',
#  13: 'yankee',
#  14: 'amiga',
#  15: 'joyas',
#  16: 'polica',
#  17: 'impactante',
#  18: 'sufre',
#  19: 'ser',
#  20: 'ahora',
#  21: 'casa',
#  22: 'valuadas',
#  23: 'solo',
#  24: 'as',
#  25: 'dinero',
#  26: 'hoy',
#  27: 'amigo',
#  28: 'rob',
#  29: 'delito',
#  30: 'vehculo',
#  31: 'mil',
#  32: 'corrupcin',
#  33: 'ver',
#  34: 'hace',
#  35: 'no',
#  36: 'vehculos',
#  37: 'el',
#  38: 'mano',
#  39: 'gente',
#  40: 'de',
#  41: 'saqueo',
#  42: 'tan',
#  43: 'pas',
#  44: 'puede',
#  45: 'intento',
#  46: 'detienen',
#  47: 'mismo',
#  48: 'parte',
#  49: 'seguro',
#  50: 'falta',
#  51: 'gran',
#  52: 'hacer',
#  53: 'bien',
#  54: 'vez',
#  55: 'pueblo',
#  56: 'siempre',
#  57: 'despus',
#  58: 'descarado',
#  59: 'menos',
#  60: 'tras',
#  61: 'auto',
#  62: 'san',
#  63: 'detiene',
#  64: 'decir',
#  65: 'plata',
#  66: 'suerte',
#  67: 'gobierno',
#  68: 'video',
#  69: 'robos',
#  70: 'tres',
#  71: 'hombre',
#  72: 'la',
#  73: 'voy',
#  74: 'denuncia',
#  75: 'violencia',
#  76: 'armada',
#  77: 'hizo',
#  78: 'mal',
#  79: 'das',
#  80: 'celular',
#  81: 'intensidad',
#  82: 'alguien',
#  83: 'bueno',
#  84: 'presidente',
#  85: 'dice',
#  86: 'en',
#  87: 'nunca',
#  88: 'cuenta',
#  89: 'mayor',
#  90: 'personas',
#  91: 'ganas',
#  92: 'jajajaja',
#  93: 'detenidos',
#  94: 'cmo',
#  95: 'jajaja',
#  96: 'sujeto',
#  97: 'detenido',
#  98: 'vida',
#  99: 'mejor',
#  100: 'caso',
#  101: 'cada',
#  102: 'mxico',
#  103: 'sigue',
#  104: 'banda',
#  105: 'acusado',
#  106: 'foto',
#  107: 'mcgregor',
#  108: 'mujer',
#  109: 'toda',
#  110: 'cara',
#  111: 'igual',
#  112: 'ao',
#  113: 'dios',
#  114: 'quiero',
#  115: 'combate',
#  116: 'historia',
#  117: 'cuatro',
#  118: 'camin',
#  119: 'tener',
#  120: 'asalto',
#  121: 'favor',
#  122: 'prisin',
#  123: 'nadie',
#  124: 'ayer',
#  125: 'pesos',
#  126: 'primer',
#  127: 'conor',
#  128: 'ladrones',
#  129: 'cosas',
#  130: 'vaya',
#  131: 'puta',
#  132: 'corazn',
#  133: 'van',
#  134: 'ir',
#  135: 'venezuela',
#  136: 'es',
#  137: 'metro',
#  138: 'claro',
#  139: 'vos',
#  140: 'hicieron',
#  141: 'hombres',
#  142: 'paso',
#  143: 'policas',
#  144: 'partido',
#  145: 'gracias',
#  146: 'joven',
#  147: 'venezolanos',
#  148: 'seguridad',
#  149: 'aqu',
#  150: 'usted',
#  151: 'sido',
#  152: 'nacional',
#  153: 'etc',
#  154: 'roban',
#  155: 'asi',
#  156: 'grande',
#  157: 'madre',
#  158: 'todas',
#  159: 'debe',
#  160: 'hecho',
#  161: 'que',
#  162: 'creo',
#  163: 'combustibles',
#  164: 'llama',
#  165: 'tiempo',
#  166: 'verdad',
#  167: 'ustedes',
#  168: 'qu',
#  169: 'nuevo',
#  170: 'dijo',
#  171: 'final',
#  172: 'pasa',
#  173: 'penal',
#  174: 'casi',
#  175: 'ladrn',
#  176: 'proceso',
#  177: 'agua',
#  178: 'habitacin',
#  179: 'maana',
#  180: 'nivel',
#  181: 'informacin',
#  182: 'tipo',
#  183: 'persona',
#  184: 'se',
#  185: 'robar',
#  186: 'momento',
#  187: 'estatal',
#  188: 'delitos',
#  189: 'madrid',
#  190: 'hambre',
#  191: 'pagar',
#  192: 'hacen',
#  193: 'mierda',
#  194: 'estn',
#  195: 'acuerdo',
#  196: 'ataque',
#  197: 'pueden',
#  198: 'carabineros',
#  199: 'obesidad',
#  200: 'permitir',
#  201: 'nada',
#  202: 'luego',
#  203: 'plebiscito',
#  204: 'arrestado',
#  205: 'ms',
#  206: 'banco',
#  207: 'trabajo',
#  208: 'advisors',
#  209: 'moldeando',
#  210: 'fintech',
#  211: 'delincuente',
#  212: 'asegura',
#  213: 'fiscala',
#  214: 'calle',
#  215: 'pblico',
#  216: 'viene',
#  217: 'pues',
#  218: 'vctima',
#  219: 'luz',
#  220: 'puedo',
#  221: 'nico',
#  222: 'cuesta',
#  223: 'cosa',
#  224: 'quiere',
#  225: 'semana',
#  226: 'propiedad',
#  227: 'parece',
#  228: 'justicia',
#  229: 'cristina',
#  230: 'mientras',
#  231: 'jajajajaja',
#  232: 'todo',
#  233: 'puebla',
#  234: 'sujetos',
#  235: 'veo',
#  236: 'peor',
#  237: 'jaja',
#  238: 'twitter',
#  239: 'fraude',
#  240: 'hijo',
#  241: 'corrupto',
#  242: 'robaron',
#  243: 'medio',
#  244: 'deben',
#  245: 'ah',
#  246: 'general',
#  247: 'millonario',
#  248: 'relojes',
#  249: 'delincuentes',
#  250: 'mira',
#  251: 'presunto',
#  252: 'social',
#  253: 'juan',
#  254: 'hora',
#  255: 'transporte',
#  256: 'conductor',
#  257: 'hablar',
#  258: 'entonces',
#  259: 'ahre',
#  260: 'var',
#  261: 'fotos',
#  262: 'vas',
#  263: 'plan',
#  264: 'abuso',
#  265: 'centro',
#  266: 'familia',
#  267: 'mundo',
#  268: 'hidrocarburos',
#  269: 'vergenza',
#  270: 'eso',
#  271: 'debera',
#  272: 'empresa',
#  273: 'arrestan',
#  274: 'resultados',
#  275: 'pertenencias',
#  276: 'supuesto',
#  277: 'camioneta',
#  278: 'hermano',
#  279: 'datos',
#  280: 'buenos',
#  281: 'asesinato',
#  282: 'pais',
#  283: 'sistema',
#  284: 'evitar',
#  285: 'mediante',
#  286: 'gol',
#  287: 'detuvieron',
#  288: 'impuestos',
#  289: 'slo',
#  290: 'manera',
#  291: 'seor',
#  292: 'moto',
#  293: 'mala',
#  294: 'haciendo',
#  295: 'miami',
#  296: 'noticias',
#  297: 'los',
#  298: 'fiscal',
#  299: 'sabe',
#  300: 'criminal',
#  301: 'identidad',
#  302: 'carlos',
#  303: 'vamos',
#  304: 'inseguridad',
#  305: 'ansiedad',
#  306: 'por',
#  307: 'dar',
#  308: 'vivienda',
#  309: 'violento',
#  310: 'grave',
#  311: 'costosos',
#  312: 'digo',
#  313: 'tal',
#  314: 'preso',
#  315: 'nacin',
#  316: 'meme',
#  317: 'hijos',
#  318: 'estrategia',
#  319: 'dicen',
#  320: 'acabo',
#  321: 'sabotaje',
#  322: 'color',
#  323: 'sos',
#  324: 'preventiva',
#  325: 'gas',
#  326: 'nmero',
#  327: 'tambien',
#  328: 'rata',
#  329: 'beso',
#  330: 'yo',
#  331: 'sabes',
#  332: 'deja',
#  333: 'an',
#  334: 'menor',
#  335: 'devuelva',
#  336: 'ro',
#  337: 'recupera',
#  338: 'votar',
#  339: 'colombia',
#  340: 'gasolina',
#  341: 'cuanto',
#  342: 'del',
#  343: 'cambio',
#  344: 'iba',
#  345: 'roba',
#  346: 'sueo',
#  347: 'vandalismo',
#  348: 'siglo',
#  349: 'veces',
#  350: 'ley',
#  351: 'via',
#  352: 'mentira',
#  353: 'atencin',
#  354: 'muerte',
#  355: 'tampoco',
#  356: 'encima',
#  357: 'hurto',
#  358: 'sino',
#  359: 'autos',
#  360: 'ivss',
#  361: 'primero',
#  362: 'fin',
#  363: 'necesidad',
#  364: 'macri',
#  365: 'llevan',
#  366: 'ac',
#  367: 'dio',
#  368: 'pemex',
#  369: 'luchador',
#  370: 'ayudar',
#  371: 'apresa',
#  372: 'tu',
#  373: 'nueva',
#  374: 'seguir',
#  375: 'congreso',
#  376: 'un',
#  377: 'gana',
#  378: 'espero',
#  379: 'segundo',
#  380: 'cabeza',
#  381: 'arma',
#  382: 'pasado',
#  383: 'mantenimiento',
#  384: 'dao',
#  385: 'haber',
#  386: 'tienda',
#  387: 'denunciar',
#  388: 'le',
#  389: 'frustra',
#  390: 'incitando',
#  391: 'elementos',
#  392: 'vigente',
#  393: 'mdico',
#  394: 'tiros',
#  395: 'organizacin',
#  396: 'estado',
#  397: 'viejo',
#  398: 'idea',
#  399: 'diario',
#  400: 'me',
#  401: 'cualquier',
#  402: 'doble',
#  403: 'quieren',
#  404: 'cierto',
#  405: 'dia',
#  406: 'armas',
#  407: 'investigacin',
#  408: 'descubre',
#  409: 'chavez',
#  410: 'lo',
#  411: 'recursos',
#  412: 'central',
#  413: 'puto',
#  414: 'sensibilidad',
#  415: 'noche',
#  416: 'nombre',
#  417: 'secuestro',
#  418: 's',
#  419: 'estan',
#  420: 'justo',
#  421: 'mam',
#  422: 'despues',
#  423: 'llevo',
#  424: 'habla',
#  425: 'culpa',
#  426: 'mensajes',
#  427: 'alerta',
#  428: 'horas',
#  429: 'original',
#  430: 'cubre',
#  431: 'civil',
#  432: 'pena',
#  433: 'basta',
#  434: 'forma',
#  435: 'misma',
#  436: 'acaba',
#  437: 'hola',
#  438: 'probable',
#  439: 'tremendo',
#  440: 'permiso',
#  441: 'amor',
#  442: 'dolor',
#  443: 'pruebas',
#  444: 'hermana',
#  445: 'nios',
#  446: 'hago',
#  447: 'conmigo',
#  448: 'meses',
#  449: 'comer',
#  450: 'fuerza',
#  451: 'detuvo',
#  452: 'serie',
#  453: 'privada',
#  454: 'homicidio',
#  455: 'guardia',
#  456: 'energa',
#  457: 'carro',
#  458: 'escuela',
#  459: 'odio',
#  460: 'autor',
#  461: 'te',
#  462: 'sale',
#  463: 'jajajajajaja',
#  464: 'ay',
#  465: 'ganado',
#  466: 'crcel',
#  467: 'precio',
#  468: 'todava',
#  469: 'adems',
#  470: 'delincuencia',
#  471: 'elctrico',
#  472: 'comercio',
#  473: 'tripulacin',
#  474: 'tractocamiones',
#  475: 'autoridades',
#  476: 'colonia',
#  477: 'diciendo',
#  478: 'rt',
#  479: 'aunque',
#  480: 'alto',
#  481: 'cmplice',
#  482: 'lugar',
#  483: 'calificado',
#  484: 'equipo',
#  485: 'emocional',
#  486: 'poder',
#  487: 'salud',
#  488: 'novio',
#  489: 'sola',
#  490: 'minutos',
#  491: 'sufri',
#  492: 'llorar',
#  493: 'ciudad',
#  494: 'tema',
#  495: 'responsable',
#  496: 'miles',
#  497: 'agresin',
#  498: 'agravado',
#  499: 'viajaba',
#  500: 'subterrneo',
#  501: 'par',
#  502: 'posible',
#  503: 'autopartes',
#  504: 'siento',
#  505: 'dolares',
#  506: 'como',
#  507: 'levante',
#  508: 'buen',
#  509: 'instagram',
#  510: 'siendo',
#  511: 'estafa',
#  512: 'paz',
#  513: 'menores',
#  514: 'pap',
#  515: 'anda',
#  516: 'lpez',
#  517: 'robando',
#  518: 'saben',
#  519: 'segn',
#  520: 'santa',
#  521: 'servicio',
#  522: 'frente',
#  523: 'violacin',
#  524: 'tenia',
#  525: 'intimidacin',
#  526: 'algn',
#  527: 'favorito',
#  528: 'obrador',
#  529: 'motocicleta',
#  530: 'lado',
#  531: 'protegerte',
#  532: 'libre',
#  533: 'caraduras',
#  534: 'frustrado',
#  535: 'justifica',
#  536: 'uso',
#  537: 'total',
#  538: 'impunidad',
#  539: 'marzo',
#  540: 'domingo',
#  541: 'valladolid',
#  542: 'dnde',
#  543: 'inters',
#  544: 'vivir',
#  545: 'pobre',
#  546: 'boca',
#  547: 'nio',
#  548: 'documentos',
#  549: 'pasar',
#  550: 'escobar',
#  551: 'pbi',
#  552: 'mes',
#  553: 'dije',
#  554: 'queda',
#  555: 'padre',
#  556: 'nota',
#  557: 'cinco',
#  558: 'presidencia',
#  559: 'defendi',
#  560: 'sacrlego',
#  561: 'boxeador',
#  562: 'euros',
#  563: 'coberturas',
#  564: 'eliges',
#  565: 'alojan',
#  566: 'elctrica',
#  567: 'ellos',
#  568: 'dentro',
#  569: 'barrio',
#  570: 'combatir',
#  571: 'todos',
#  572: 'daos',
#  573: 'unas',
#  574: 'memes',
#  575: 'robado',
#  576: 'facebook',
#  577: 'bastante',
#  578: 'libertad',
#  579: 'realidad',
#  580: 'grupo',
#  581: 'ojal',
#  582: 'denuncian',
#  583: 'muerto',
#  584: 'cae',
#  585: 'investiga',
#  586: 'ssp',
#  587: 'ninguna',
#  588: 'amlo',
#  589: 'bicicleta',
#  590: 'beach',
#  591: 'dan',
#  592: 'aseguran',
#  593: 'autoridad',
#  594: 'co',
#  595: 'responsables',
#  596: 'mexicanos',
#  597: 'real',
#  598: 'serio',
#  599: 'dedicada',
#  600: 'redujo',
#  601: 'rotondaro',
#  602: 'hacia',
#  603: 'sra',
#  604: 'llamar',
#  605: 'lpm',
#  606: 'fav',
#  607: 'imagen',
#  608: 'dignidad',
#  609: 'quin',
#  610: 'ya',
#  611: 'pedo',
#  612: 'cuba',
#  613: 'punto',
#  614: 'mucha',
#  615: 'llevaron',
#  616: 'hablando',
#  617: 'capital',
#  618: 'sexual',
#  619: 'resultado',
#  620: 'prescribe',
#  621: 'manolo',
#  622: 'sabemos',
#  623: 'bajo',
#  624: 'muri',
#  625: 'anoche',
#  626: 'municipal',
#  627: 'venezolano',
#  628: 'seora',
#  629: 'esto',
#  630: 'acusados',
#  631: 'parque',
#  632: 'presuntos',
#  633: 'hice',
#  634: 'hostias',
#  635: 'termine',
#  636: 'sol',
#  637: 'buenas',
#  638: 'miedo',
#  639: 'comida',
#  640: 'qued',
#  641: 'juez',
#  642: 'alta',
#  643: 'chvez',
#  644: 'negocio',
#  645: 'menudo',
#  646: 'gato',
#  647: 'tweet',
#  648: 'loco',
#  649: 'crisis',
#  650: 'puesto',
#  651: 'extorsin',
#  652: 'rbitro',
#  653: 'ganar',
#  654: 'primera',
#  655: 'papa',
#  656: 'masivo',
#  657: 'argentinos',
#  658: 'pobres',
#  659: 'dejo',
#  660: 'pago',
#  661: 'ningn',
#  662: 'buena',
#  663: 'mochila',
#  664: 'trabajar',
#  665: 'corruptos',
#  666: 'juego',
#  667: 'rato',
#  668: 'tarde',
#  669: 'haga',
#  670: 'vino',
#  671: 'recuperan',
#  672: 'junto',
#  673: 'catrillanca',
#  674: 'argentina',
#  675: 'ces',
#  676: 'oms',
#  677: 'homicidios',
#  678: 'consagradas',
#  679: 'esperan',
#  680: 'balazos',
#  681: 'producto',
#  682: 'cloro',
#  683: 'causa',
#  684: 'repblica',
#  685: 'habl',
#  686: 'acciones',
#  687: 'gan',
#  688: 'delictiva',
#  689: 'triste',
#  690: 'reportan',
#  691: 'funcionarios',
#  692: 'informa',
#  693: 'motochorro',
#  694: 'legal',
#  695: 'media',
#  696: 'gusta',
#  697: 'puedes',
#  698: 'fue',
#  699: 'asesinatos',
#  700: 'deberan',
#  701: 'penales',
#  702: 'lindo',
#  703: 'orto',
#  704: 'pudo',
#  705: 'pinche',
#  706: 'ladron',
#  707: 'aqui',
#  708: 'volver',
#  709: 'importa',
#  710: 'gastos',
#  711: 'chile',
#  712: 'europa',
#  713: 'llega',
#  714: 'falsos',
#  715: 'lunes',
#  716: 'hija',
#  717: 'santos',
#  718: 'air',
#  719: 'juicio',
#  720: 'detencin',
#  721: 'zona',
#  722: 'existe',
#  723: 'municipio',
#  724: 'pblica',
#  725: 'ruta',
#  726: 'unidades',
#  727: 'sagrario',
#  728: 'copones',
#  729: 'titular',
#  730: 'ma',
#  731: 'siete',
#  732: 'estatales',
#  733: 'edo',
#  734: 'maduro',
#  735: 'estudios',
#  736: 'para',
#  737: 'asco',
#  738: 'jajajajajajaja',
#  739: 'all',
#  740: 'espaa',
#  741: 'puro',
#  742: 'hay',
#  743: 'denunci',
#  744: 'justificar',
#  745: 'club',
#  746: 'condena',
#  747: 'dems',
#  748: 'unidad',
#  749: 'perro',
#  750: 'increble',
#  751: 'petrleo',
#  752: 'bro',
#  753: 'victima',
#  754: 'siquiera',
#  755: 'vivo',
#  756: 'che',
#  757: 'fondos',
#  758: 'tapar',
#  759: 'hdp',
#  760: 'mujeres',
#  761: 'fuego',
#  762: 'ayuda',
#  763: 'lleg',
#  764: 'cuantos',
#  765: 'departamento',
#  766: 'interior',
#  767: 'patrimonio',
#  768: 'extrao',
#  769: 'ven',
#  770: 'cigarrillos',
#  771: 'ciudadanos',
#  772: 'orden',
#  773: 'pedro',
#  774: 'vinculacin',
#  775: 'captan',
#  776: 'logr',
#  777: 'polticos',
#  778: 'acto',
#  779: 'eeuu',
#  780: 'mercanca',
#  781: 'cometido',
#  782: 'entran',
#  783: 'cel',
#  784: 'chavismo',
#  785: 'esperar',
#  786: 'vuelve',
#  787: 'crescenti',
#  788: 'pea',
#  789: 'bancos',
#  790: 'trata',
#  791: 'diarios',
#  792: 'denuncias',
#  793: 'maldito',
#  794: 'impuesto',
#  795: 'visto',
#  796: 'novia',
#  797: 'perdn',
#  798: 'pongo',
#  799: 'dias',
#  800: 'hablo',
#  801: 'control',
#  802: 'escandaloso',
#  803: 'campo',
#  804: 'cuello',
#  805: 'redes',
#  806: 'chelsea',
#  807: 'problema',
#  808: 'amo',
#  809: 'red',
#  810: 'feliz',
#  811: 'vale',
#  812: 'cfk',
#  813: 'puso',
#  814: 'malo',
#  815: 'chica',
#  816: 'recuerdo',
#  817: 'varios',
#  818: 'dormir',
#  819: 'leer',
#  820: 'empresas',
#  821: 'profesoras',
#  822: 'hablan',
#  823: 'doy',
#  824: 'cundo',
#  825: 'cajero',
#  826: 'normal',
#  827: 'tesoro',
#  828: 'urgente',
#  829: 'aparte',
#  830: 'elecciones',
#  831: 'comprar',
#  832: 'ejemplo',
#  833: 'den',
#  834: 'inversin',
#  835: 'lnea',
#  836: 'carne',
#  837: 'lucha',
#  838: 'fujimorista',
#  839: 'vinculado',
#  840: 'afirma',
#  841: 'dej',
#  842: 'apoyo',
#  843: 'sector',
#  844: 'apagn',
#  845: 'william',
#  846: 'mordidas',
#  847: 'puntos',
#  848: 'quedar',
#  849: 'destruccin',
#  850: 'izquierda',
#  851: 'po',
#  852: 'voto',
#  853: 'llegar',
#  854: 'internet',
#  855: 'tercer',
#  856: 'una',
#  857: 'dicho',
#  858: 'con',
#  859: 'pdi',
#  860: 'sacar',
#  861: 'jams',
#  862: 'autoestima',
#  863: 'sea',
#  864: 'moral',
#  865: 'humor',
#  866: 'simple',
#  867: 'tambin',
#  868: 'chiquito',
#  869: 'mmm',
#  870: 'manejo',
#  871: 'problemas',
#  872: 'dejar',
#  873: 'verga',
#  874: 'poca',
#  875: 'coo',
#  876: 'estabilidad',
#  877: 'compra',
#  878: 'llorando',
#  879: 'incompetencia',
#  880: 'sociales',
#  881: 'hablas',
#  882: 'mio',
#  883: 'empezar',
#  884: 'poner',
#  885: 'campaa',
#  886: 'verdadero',
#  887: 'las',
#  888: 'pelo',
#  889: 'esperando',
#  890: 'algo',
#  891: 'rojo',
#  892: 'punta',
#  893: 'hidrocarburo',
#  894: 'afp',
#  895: 'creer',
#  896: 'huachicol',
#  897: 'pide',
#  898: 'investigan',
#  899: 'premian',
#  900: 'barriles',
#  901: 'basura',
#  902: 'fge',
#  903: 'sali',
#  904: 'amigos',
#  905: 'viendo',
#  906: 'local',
#  907: 'corrupcion',
#  908: 'oro',
#  909: 'alguna',
#  910: 'reales',
#  911: 'jugador',
#  912: 'afecta',
#  913: 'seis',
#  914: 'comisin',
#  915: 'saqueos',
#  916: 'vea',
#  917: 'automvil',
#  918: 'kari',
#  919: 'innegable',
#  920: 'evidencian',
#  921: 'venezolana',
#  922: 'buscar',
#  923: 'ciudadano',
#  924: 'equipos',
#  925: 'resisti',
#  926: 'aumento',
#  927: 'pesar',
#  928: 'tierras',
#  929: 'representacion',
#  930: 'guerra',
#  931: 'al',
#  932: 'saab',
#  933: 'totalmente',
#  934: 'descaro',
#  935: 'error',
#  936: 'periodista',
#  937: 'derecho',
#  938: 'razn',
#  939: 'confianza',
#  940: 'frustrar',
#  941: 'devolver',
#  942: 'piensa',
#  943: 'm',
#  944: 'asqueroso',
#  945: 'obvio',
#  946: 'bipolaridad',
#  947: 'onda',
#  948: 'siguen',
#  949: 'seores',
#  950: 'baja',
#  951: 'inestabilidad',
#  952: 'tuit',
#  953: 'river',
#  954: 'ministro',
#  955: 'reportar',
#  956: 'solamente',
#  957: 'excusa',
#  958: 'colectivo',
#  959: 'pri',
#  960: 'sigo',
#  961: 'y',
#  962: 'pasada',
#  963: 'ropa',
#  964: 'mundial',
#  965: 'copa',
#  966: 'bebs',
#  967: 'hagan',
#  968: 'vecino',
#  969: 'ineficiencia',
#  970: 'terminar',
#  971: 'viva',
#  972: 'padres',
#  973: 'haces',
#  974: 'ahorro',
#  975: 'vieja',
#  976: 'ello',
#  977: 'carta',
#  978: 'comn',
#  979: 'pero',
#  980: 'psg',
#  981: 'pregunta',
#  982: 'barcelona',
#  983: 'vctimas',
#  984: 'celulares',
#  985: 'goles',
#  986: 'ojala',
#  987: 'cantidad',
#  988: 'so',
#  989: 'pensando',
#  990: 'ti',
#  991: 'culpable',
#  992: 'diga',
#  993: 'habia',
#  994: 'mvil',
#  995: 'entro',
#  996: 'chorra',
#  997: 'noticia',
#  998: 'vdeo',
#  999: 'us',
#  ...}

# %%
text_data = text_to_numbers(datos_limp, word_dict)
text_data[0]
# Out:
# [4152,
#  5002,
#  0,
#  5002,
#  0,
#  4152,
#  5002,
#  0,
#  5002,
#  0,
#  0,
#  4152,
#  4301,
#  1655,
#  0,
#  4152,
#  5002,
#  0,
#  5002]

# %%
valid_examples = [word_dict[x] for x in valid_words]

# %%
valid_examples
# Out:
# [1546, 1492, 1207]

# %%
#validar 1 negativo
target = [1 for ix, x in enumerate(datos_limp)]
len(target)
# Out:
# 10651

# %%
def generate_batch_data(sentences, batch_size, window_size, method = 'skip_gram'):
    '''
        Mi perro come su comida -> (Mi, come), (perro, come), (su, come), (comida, come)
    '''
    batch_data = []
    label_data = []
    
    while len(batch_data) < batch_size:
        rand_sentences = np.random.choice(sentences)
        window_seq = [rand_sentences[max((ix-window_size),0):(ix+window_size+1)] 
                      for ix, x in enumerate(rand_sentences)]
        label_idx = [ix if ix < window_size else window_size for ix, x in enumerate(window_seq)]
        
        if method == 'skip_gram':
            batch_and_labels = [(x[y], x[:y]+x[(y+1):]) for x,y in zip(window_seq, label_idx)]
            tuple_data = [(x,y_) for x, y in batch_and_labels for y_ in y]
        else:
            raise ValueError("Método {} no implementado".format(method))
        
        batch, labels = [list(x) for x in zip(*tuple_data)]
        batch_data.extend(batch[:batch_size])
        label_data.extend(labels[:batch_size])
        
    batch_data = batch_data[:batch_size]
    label_data = label_data[:batch_size]
    
    batch_data = np.array(batch_data)
    label_data = np.transpose(np.array([label_data]))
    
    return (batch_data, label_data)

# %%
import tensorflow as tf
import numpy as np

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1, 1))
x_inputs = tf.placeholder(tf.int32, shape =[batch_size])
y_target = tf.placeholder(tf.int32, shape = [batch_size,1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
# Out:
# WARNING:tensorflow:From C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
embed = tf.nn.embedding_lookup(embeddings, x_inputs)

# %%
nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                              stddev=1.0/np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %%
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights, biases=nce_biases,
                                    inputs=embed, labels=y_target, 
                                     num_sampled = num_sampled, num_classes=vocabulary_size))

# %%
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings),1, keepdims=True))
normalized_embeddings = embeddings/norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0).minimize(loss)
# Out:
# WARNING:tensorflow:From C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
session = tf.Session()
init = tf.global_variables_initializer()
session.run(init)

# %%
loss_vect = []
loss_x_vect = []
for i in range(generations):
    batch_inputs, batch_labels = generate_batch_data(text_data, batch_size, window_size)
    feed_dict = {x_inputs: batch_inputs, y_target: batch_labels}
    session.run(optimizer, feed_dict=feed_dict)
    
    if (i+1) % print_loss_every == 0:
        loss_val = session.run(loss, feed_dict=feed_dict)
        loss_vect.append(loss_val)
        loss_x_vect.append(i+1)
        print("Iteración {}, Pérdida: {}".format(i+1, loss_val))
    
    ## Validación de palabras más cercanas a las 5 seleccionadas
    if (i+1) % print_valid_every == 0:
        sim = session.run(similarity, feed_dict=feed_dict)
        for j in range(len(valid_words)):
            valid_word = word_dict_rev[valid_examples[j]]
            top_k = 10
            nearest = (-sim[j,:]).argsort()[1:top_k+1]
            log_string = "Palabras cercanas a {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dict_rev[nearest[k]]
                log_string = "%s %s, "%(log_string, close_word)
            print(log_string)
# Out:
# Iteración 500, Pérdida: 8.039772033691406
# Iteración 1000, Pérdida: 16.55388641357422
# Iteración 1500, Pérdida: 36.76530838012695
# Iteración 2000, Pérdida: 24.588407516479492
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 2500, Pérdida: 8.57458782196045
# Iteración 3000, Pérdida: 7.421785354614258
# Iteración 3500, Pérdida: 15.8325834274292
# Iteración 4000, Pérdida: 1.8386590480804443
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 4500, Pérdida: 8.084177017211914
# Iteración 5000, Pérdida: 0.5604620575904846
# Iteración 5500, Pérdida: 8.918204307556152
# Iteración 6000, Pérdida: 1.4390617609024048
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 6500, Pérdida: 8.581886291503906
# Iteración 7000, Pérdida: 1.6866941452026367
# Iteración 7500, Pérdida: 0.9033330678939819
# Iteración 8000, Pérdida: 0.5842766165733337
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 8500, Pérdida: 1.3550810813903809
# Iteración 9000, Pérdida: 0.685279130935669
# Iteración 9500, Pérdida: 1.6610242128372192
# Iteración 10000, Pérdida: 0.1719096601009369
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 10500, Pérdida: 1.0018752813339233
# Iteración 11000, Pérdida: 0.574364185333252
# Iteración 11500, Pérdida: 0.6106707453727722
# Iteración 12000, Pérdida: 0.7909349203109741
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 12500, Pérdida: 2.181713104248047
# Iteración 13000, Pérdida: 0.9371249675750732
# Iteración 13500, Pérdida: 0.5399532914161682
# Iteración 14000, Pérdida: 1.328799843788147
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 14500, Pérdida: 0.4839302897453308
# Iteración 15000, Pérdida: 0.26747453212738037
# Iteración 15500, Pérdida: 0.32703885436058044
# Iteración 16000, Pérdida: 1.4282912015914917
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 16500, Pérdida: 1.5644938945770264
# Iteración 17000, Pérdida: 0.8384345173835754
# Iteración 17500, Pérdida: 1.302351713180542
# Iteración 18000, Pérdida: 2.1890225410461426
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 18500, Pérdida: 7.302945137023926
# Iteración 19000, Pérdida: 0.9058068990707397
# Iteración 19500, Pérdida: 0.6242366433143616
# Iteración 20000, Pérdida: 1.2534600496292114
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 20500, Pérdida: 1.012932300567627
# Iteración 21000, Pérdida: 0.7532045245170593
# Iteración 21500, Pérdida: 1.108647346496582
# Iteración 22000, Pérdida: 1.3006255626678467
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 22500, Pérdida: 0.8271862864494324
# Iteración 23000, Pérdida: 0.6515552997589111
# Iteración 23500, Pérdida: 0.4680253565311432
# Iteración 24000, Pérdida: 0.3065764307975769
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 24500, Pérdida: 0.6129859089851379
# Iteración 25000, Pérdida: 0.6432222723960876
# Iteración 25500, Pérdida: 0.9491915106773376
# Iteración 26000, Pérdida: 1.3922659158706665
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 26500, Pérdida: 1.0175424814224243
# Iteración 27000, Pérdida: 0.3863224387168884
# Iteración 27500, Pérdida: 2.326456069946289
# Iteración 28000, Pérdida: 0.4204767346382141
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 28500, Pérdida: 0.3149867355823517
# Iteración 29000, Pérdida: 1.1218785047531128
# Iteración 29500, Pérdida: 0.7525272965431213
# Iteración 30000, Pérdida: 0.3381718397140503
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 30500, Pérdida: 0.6789681315422058
# Iteración 31000, Pérdida: 1.0902553796768188
# Iteración 31500, Pérdida: 1.6249897480010986
# Iteración 32000, Pérdida: 0.6617197394371033
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 32500, Pérdida: 0.9430350661277771
# Iteración 33000, Pérdida: 0.5359370708465576
# Iteración 33500, Pérdida: 4.100840091705322
# Iteración 34000, Pérdida: 2.3507533073425293
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 34500, Pérdida: 0.5500502586364746
# Iteración 35000, Pérdida: 0.6828354001045227
# Iteración 35500, Pérdida: 1.1465530395507812
# Iteración 36000, Pérdida: 0.3719501495361328
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 36500, Pérdida: 0.5439695119857788
# Iteración 37000, Pérdida: 0.5567653775215149
# Iteración 37500, Pérdida: 0.834822416305542
# Iteración 38000, Pérdida: 0.38136059045791626
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 38500, Pérdida: 0.46321389079093933
# Iteración 39000, Pérdida: 0.9862750172615051
# Iteración 39500, Pérdida: 0.932060718536377
# Iteración 40000, Pérdida: 0.4411226212978363
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 40500, Pérdida: 2.6816742420196533
# Iteración 41000, Pérdida: 0.9992572069168091
# Iteración 41500, Pérdida: 0.5969284772872925
# Iteración 42000, Pérdida: 0.7319217920303345
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 42500, Pérdida: 1.144586443901062
# Iteración 43000, Pérdida: 0.6397528648376465
# Iteración 43500, Pérdida: 0.7297245860099792
# Iteración 44000, Pérdida: 0.758056104183197
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 44500, Pérdida: 0.5811478495597839
# Iteración 45000, Pérdida: 0.7240129113197327
# Iteración 45500, Pérdida: 0.7343136072158813
# Iteración 46000, Pérdida: 0.8311374187469482
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 46500, Pérdida: 1.0098838806152344
# Iteración 47000, Pérdida: 0.6540860533714294
# Iteración 47500, Pérdida: 0.48952656984329224
# Iteración 48000, Pérdida: 1.1360434293746948
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,
# Iteración 48500, Pérdida: 1.1385831832885742
# Iteración 49000, Pérdida: 0.7942125797271729
# Iteración 49500, Pérdida: 0.4033748507499695
# Iteración 50000, Pérdida: 0.708598256111145
# Palabras cercanas a policia: curules,  contame,  argentinos,  drogadicto,  alcalde,  empezando,  disposici,  azul,  capaz,  redondo,
# Palabras cercanas a modalidad: capturada,  robono,  migratorio,  camisa,  chest,  mito,  flagrante,  novias,  ua,  decime,
# Palabras cercanas a atraco: colectivo,  revisan,  anteto,  conserva,  cllate,  atiende,  mejorar,  coordinadora,  orejas,  lave,

# %% [markdown]
# ### Keras

# %%
from keras_preprocessing import text

# %%
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(datos_limp)

# %%
word2id = tokenizer.word_index
id2word = {v:k for k, v in word2id.items()}

# %%
vocab_size = len(word2id) + 1 
embed_size = 100

# %%
wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in datos_limp]
print('Vocabulary Size:', vocab_size)
print('Vocabulary Sample:', list(word2id.items())[:100])
# Out:
# Vocabulary Size: 17106
# Vocabulary Sample: [('robo', 1), ('si', 2), ('millones', 3), ('dos', 4), ('va', 5), ('aos', 6), ('reporte', 7), ('dlares', 8), ('mas', 9), ('combustible', 10), ('da', 11), ('daddy', 12), ('yankee', 13), ('amiga', 14), ('joyas', 15), ('polica', 16), ('impactante', 17), ('sufre', 18), ('ser', 19), ('ahora', 20), ('casa', 21), ('valuadas', 22), ('solo', 23), ('as', 24), ('dinero', 25), ('hoy', 26), ('amigo', 27), ('rob', 28), ('delito', 29), ('vehculo', 30), ('mil', 31), ('corrupcin', 32), ('ver', 33), ('hace', 34), ('no', 35), ('vehculos', 36), ('el', 37), ('mano', 38), ('gente', 39), ('de', 40), ('saqueo', 41), ('tan', 42), ('pas', 43), ('puede', 44), ('intento', 45), ('detienen', 46), ('mismo', 47), ('parte', 48), ('seguro', 49), ('falta', 50), ('gran', 51), ('hacer', 52), ('bien', 53), ('vez', 54), ('pueblo', 55), ('siempre', 56), ('despus', 57), ('descarado', 58), ('menos', 59), ('tras', 60), ('auto', 61), ('san', 62), ('detiene', 63), ('decir', 64), ('plata', 65), ('suerte', 66), ('gobierno', 67), ('video', 68), ('robos', 69), ('tres', 70), ('hombre', 71), ('la', 72), ('voy', 73), ('denuncia', 74), ('violencia', 75), ('armada', 76), ('hizo', 77), ('mal', 78), ('das', 79), ('celular', 80), ('intensidad', 81), ('alguien', 82), ('bueno', 83), ('presidente', 84), ('dice', 85), ('en', 86), ('nunca', 87), ('cuenta', 88), ('mayor', 89), ('personas', 90), ('ganas', 91), ('jajajaja', 92), ('detenidos', 93), ('cmo', 94), ('jajaja', 95), ('sujeto', 96), ('detenido', 97), ('vida', 98), ('mejor', 99), ('caso', 100)]

# %% [markdown]
# ### Keras

# %%
import numpy as np
np.random.seed(13)

from keras.models import Sequential, Model
from keras.layers import Embedding, Reshape, Activation, Input
from keras.layers.merge import Dot
from keras.utils import np_utils
from keras.utils.data_utils import get_file
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import skipgrams

import gensim

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(datos_limp)

# %%
V = len(tokenizer.word_index) + 1
V
# Out:
# 17106

# %%
dim_embedddings = 128

# inputs
w_inputs = Input(shape=(1, ), dtype='int32')
w = Embedding(V, dim_embedddings)(w_inputs)

# context
c_inputs = Input(shape=(1, ), dtype='int32')
c  = Embedding(V, dim_embedddings)(c_inputs)
o = Dot(axes=2)([w, c])
o = Reshape((1,), input_shape=(1, 1))(o)
o = Activation('sigmoid')(o)

SkipGram = Model(inputs=[w_inputs, c_inputs], outputs=o)
SkipGram.summary()
SkipGram.compile(loss='binary_crossentropy', optimizer='adam')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 128)       2189568     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 128)       2189568     input_2[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1, 1)         0           embedding_1[0][0]
#                                                                  embedding_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           dot_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           reshape_1[0][0]
# ==================================================================================================
# Total params: 4,379,136
# Trainable params: 4,379,136
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
for _ in range(5):
    loss = 0.
    for i, doc in enumerate(tokenizer.texts_to_sequences(datos_limp)):
        data, labels = skipgrams(sequence=doc, vocabulary_size=V, window_size=5, negative_samples=5.)
        x = [np.array(x) for x in zip(*data)]
        y = np.array(labels, dtype=np.int32)
        if x:
            loss += SkipGram.train_on_batch(x, y)

    print(loss)
# Out:
# 5144.289180833846
# 3417.9137711841613
# 3139.319450482726
# 2929.7750292615965
# 2933.212652293965

# %%
f = open('vectors.txt' ,'w')
f.write('{} {}\n'.format(V-1, dim_embedddings))
vectors = SkipGram.get_weights()[0]
for word, i in tokenizer.word_index.items():
    f.write('{} {}\n'.format(word, ' '.join(map(str, list(vectors[i, :])))))
f.close()

# %%
w2v = gensim.models.KeyedVectors.load_word2vec_format('./vectors.txt', binary=False)

# %%
w2v.most_similar(positive=['policia'])
# Out:
# [('conduca', 0.630648672580719),
#  ('francisco', 0.61998450756073),
#  ('narcomenudeo', 0.6185741424560547),
#  ('lmparas', 0.6152634024620056),
#  ('sanjuanense', 0.6050634384155273),
#  ('drogas', 0.6000219583511353),
#  ('implicados', 0.5861939191818237),
#  ('romo', 0.5757334232330322),
#  ('gaviotas', 0.5730146169662476),
#  ('recuperamos', 0.5672511458396912)]

# %%
w2v.most_similar(positive=['modalidad'])
# Out:
# [('domicilio', 0.6512517929077148),
#  ('rentar', 0.6473425626754761),
#  ('vinculan', 0.6375187039375305),
#  ('michoacn', 0.6219478845596313),
#  ('homofbico', 0.6198636889457703),
#  ('posesin', 0.6146078109741211),
#  ('n', 0.6133899688720703),
#  ('quedaron', 0.6118131875991821),
#  ('secretara', 0.6096034646034241),
#  ('colonia', 0.6056919097900391)]
